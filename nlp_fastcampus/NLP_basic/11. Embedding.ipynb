# %% [markdown]
# ## Embedding
# - 언어의 계층적 관계를 표현하기 위해 dense vector로 표현
#
# ### Dimension Reduction
# - hidden layer는 y를 구하기 위해 x의 필요정보를 작은차원으로 압축

# %% [markdown]
# ## Word Embedding
# - 단어를 연속적인 값으로 표현하려는 시도
#
# ### 언어의 특징
# - 다의어, Polysemy: 한 단어가 여러 의미
# - 동형어, Homonym: 다른 의미의 한 단어
# - => Word Sense Disambiguation이 필요
# - 동의어, Synonyms: 한 의미의 다른 단어
# - Hypernym, Hyponym: 계층구조(동물 / 원숭이)
# - => 이러한 특징들은 one-hot 인코딩을 통해 반영할 수 없음

# %% [markdown]
# ### WordNet
# - 위의 특징들을 반영하기 위한 단어사전, Thesaurus
# - 동의어, 상위어, 하위어에 대한 정보가 구축되어있는 Directed Acyclic Graph
# - NLTK 패키지에 포함
# - Korean WordNet -> KorLex, Korean WordNet
# - 계층 구조의 Graph에서 단어 사이의 거리를 측정 / sim(w, w') = -log distance(w, w')
# - Corpus(training 데이터) 없이도 단어 사이의 거리 측정이 가능
# - cons
#   - 특정 도메인 특화 수치 계산이 어려움
#   - 신조어나 사전에 등록되어 있지 않은 단어 분석이 불가능

# %%
import nltk
nltk.download('wordnet')

from nltk.corpus import wordnet as wn
# Out:
# [nltk_data] Downloading package wordnet to /home/jcwee/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /home/jcwee/nltk_data...
# [nltk_data]   Unzipping corpora/omw-1.4.zip.
# True

# %%
wn.synsets('people')
# Out:
# [Synset('people.n.01'),
#  Synset('citizenry.n.01'),
#  Synset('people.n.03'),
#  Synset('multitude.n.03'),
#  Synset('people.v.01'),
#  Synset('people.v.02')]

# %%
wn.synsets('people')[0].hypernyms()
# Out:
# [Synset('group.n.01')]

# %%
def hypernyms(word):
    current_node = wn.synsets(word)[0]
    yield current_node

    while True:
        try:
            current_node = current_node.hypernyms()[0]
            yield current_node
        except IndexError:
            break
for h in hypernyms('policeman'):
    print(h)
# Out:
# Synset('policeman.n.01')
# Synset('lawman.n.01')
# Synset('defender.n.01')
# Synset('preserver.n.03')
# Synset('person.n.01')
# Synset('causal_agent.n.01')
# Synset('physical_entity.n.01')
# Synset('entity.n.01')

# %%
[h for h in hypernyms('firefighter')]
# Out:
# [Synset('fireman.n.04'),
#  Synset('defender.n.01'),
#  Synset('preserver.n.03'),
#  Synset('person.n.01'),
#  Synset('causal_agent.n.01'),
#  Synset('physical_entity.n.01'),
#  Synset('entity.n.01')]

# %%
[h for h in hypernyms('sheriff')]
# Out:
# [Synset('sheriff.n.01'),
#  Synset('lawman.n.01'),
#  Synset('defender.n.01'),
#  Synset('preserver.n.03'),
#  Synset('person.n.01'),
#  Synset('causal_agent.n.01'),
#  Synset('physical_entity.n.01'),
#  Synset('entity.n.01')]

# %%
[h for h in hypernyms('mailman')]
# Out:
# [Synset('mailman.n.01'),
#  Synset('deliveryman.n.01'),
#  Synset('employee.n.01'),
#  Synset('worker.n.01'),
#  Synset('person.n.01'),
#  Synset('causal_agent.n.01'),
#  Synset('physical_entity.n.01'),
#  Synset('entity.n.01')]

# %%
def distance(word1, word2):
    word1_hypernyms = [h for h in hypernyms(word1)]

    for i, word2_hypernym in enumerate(hypernyms(word2)):
        try :
            return i + word1_hypernyms.index(word2_hypernym)

        except ValueError:
            continue

distance('sheriff', 'student')
# Out:
# 6

# %%
import numpy as np

def similarity(word1, word2):
    return -np.log(distance(word1, word2))

print(similarity('sheriff', 'student'))
print(similarity('sheriff', 'policeman'))
# Out:
# -1.791759469228055
# -0.6931471805599453

# %% [markdown]
# ## Data-driven Method
# - 데이터가 충분하다면 task에 특화된 활용이 가능
# ### TF-IDF
# - 단어 w의 문서 d 내에서의 중요성을 나타냄
# - TF(w, d) / DF(w)
# - TF(Term Frequency)
#   - 단어의 문서 내 출현 횟수
#   - 숫자가 클수록 중요단어
# - IDF(Inverse Document Frequency)
#   - 해당 단어가 출현한 문서 숫자의 역수
#   - 값이 클수록 일반적으로 많이 쓰이는 단어
# - 단어의 각 문서에서의 중요도를 feature로 vector화
# - TF-IDF MAtrix, 단어의 각 문서별 TF-IDF수치를 vector화
#   - row: 단어, column: 문서
# ### Co-occurrence, Based on Context Window
# - 함께 나타나는 단어들을 활용
# - context window를 사용하여 windowing을 실행
#   - 특정 단어 주변에 나타나는 단어를 비교하여 단어간의 유사도 측정
#
# #### 여전히 sparse vector로 표현되는 단점이 존재

# %% [markdown]
# ## Similarity Metrics
# - vector간의 거리를 구하는 방법
# - Manhattan Distance: dL1(w, v) = sigma(1~d) |wi - vi|
# - Euclidean Distance: dL2(w, v) = sqrt(sigma(1~d) (wi - vi) ^ 2)
# - Infinity Norm: max(|w1 - v1|, |w2 - v2|, ... )
# - Cosine Similarity: cos_sim(w, v) = (w, v).dot / |w||v|
#                                    = sigma(wi*vi) / sqrt(sigma(wi^2)) sqrt(sigma(vi^2))
# - L1, L2, Infinity는 강조하고자 하는 내용에 따라 사용
# - Cosine Similarity는 벡터의 방향을 중요시함

# %%
import pandas as pd
from collections import defaultdict

# %%
with open('review.sorted.uniq.refined.tok.tsv') as f:
    lines = [l.strip() for l in f.read().splitlines() if l.strip()]

# %%
lines
# Out:
# ['negative\t!',
#  'negative\t! 다 녹 아서 왓 어요 . . 짜증',
#  'negative\t!!!!!!!!!!!!!',
#  'negative\t!!!! 이게 뭐 야 ? 진짜 이게 뭐 야 ? 리뷰 보고 구매 했 는데 ! 나원참 !',
#  'negative\t" 싼 게 비지떡 ". 200 ml 라고 판매 하 는데 내 가 보 기 엔 절대 이거 100 ml 도 안 된다 . 뚜껑 열 다가 손톱 부러지 고 , 향기 는 에프 킬 라 . . 구매 후기 잘 안 쓰 는데 이건 진짜 최악 이 다 .',
#  'negative\t" 축 결혼 " 이 라는 리본 도 없 고 화환 하나 에 두 사람 이름 만 있 는 걸 보 니까 화 가 났 습니다 . 근처 에 화환 몇 개 놓 을 자리 도 있 었 는데 ?',
#  'negative\t" 가죽 검정 " 이 라는 상품명 에서 누구 나 알 수 있 듯 인조 가죽 느낌 의 재질 입니다 . 비닐 에 가까운 재질 이 라 진짜 인조 가 죽이 라도 저렴 한 소재 일 것 같 습니다 . 이 가격 에 사 는 사람 은 소재 에 대한 기대 는 없 을 테 지만 참고 하 시 기 바랍니다 . 패드 뒷 면 은 전면 이 양면 테이프 로 부착 되 어 있 으며 그대로 신발 에 접착 시키 는 방식 입니다 . 하지만 양면 테이프 가 강해 보이 지 않 습니다 . 신발 이 조금 만 고급 이 라도 주문 하 지 마세요 . 패드 야 며칠 못 쓰 고 떨어지 는 건 참 을 수 있 지만 신발 안감 이 상할 것 같 은 느낌 의 양면 테이프 입니다 . 일단 부착 후 3 일 간 은 신지 않 을 예정 이 며 매일 신 는 신발 도 아니 기에 생각 보다 오래 쓸 수 도 있 겠 지만 다시 구매 할 생각 은 없 습니다 .',
#  'negative\t" 루피 아니 야 " 우리 아이 말 이 에요 ㅠㅠ 루피 좋 아 하 는 우리 아이 , 항상 껴안 고 다녀 많이 헤졌 어요 . 그래서 최저 가 판매처 에서 두 개 더 구매 했 는데 기존 에 샀 던 두 개 랑 은 다른 디자인 이 네요 . 얼굴 은 이쁘 지만 , 전체 적 으로 별로 인걸요 ? 왜 이리 뚱뚱 하 고 앉 아 있 는지 . .. 몸 을 안 아야 하 는 데 앉 아 있 으니 안 고 다니 기 불편 해요 . 그냥 전 시용 인가 봐요 . 우리 애 는 새로 산 루피 는 그냥 던져 버리 고 , 때 타 고 찢어지 고 다 헤진 예전 루피 만 갖 고 노 네요 . 미미 월드 라고 적혀 는 있 어요 . 판매처 엔 3 기 라고 적혀 있 긴 한데 , 다른 판매자 들 3 기 상품 이랑 도 다른 모양 이 라 다 들 정품 인지 도 의심 스럽 네요 .',
#  'negative\t" 비싸 ~~~~ 요 " 라고 후기 를 남기 네요',
#  'negative\t" 화이트 " 로 구매 했 는데 . .. 왜 다른 제품 으로 오 죠 ? 외국 에서 배송 받 지 않 았 다면 . .. 당장 반품 인데 ~~~',
#  'negative\t" 화이트 " 로 구매 했 는데 . .. 다른 제품 으로 배송 되 어 왔 어요 ! ! 여기 가 외국 이 아니 라면 . .. 당장 반품 인데 ~~~',
#  'negative\t# 중간 . 무난 . 애매 함 간단히 입 을 바람막이 생각 하 며 구매 하 였 는데 음 . .. 기대 했 던 것 과 는 많이 다르 네요 . 색상 이 어두워서 그런 것 같 기 도 하 지만 예쁘 진 않 습니다 . 집 근처 돌아다닐 때 만 입 을 것 같 아요 . 반품 할까 하 다가 배 보다 배꼽 이 커 질까 그냥 집 에서 입 기 로 했 습니다 . 사이즈 는 100 입 는데 외투 라 그런지 조금 큽니다 . 크 게 입 으실 거 면 상관없 을 것 같 네요 . 다른 제품 은 모르 겠 으나 요건 개인 적 으론 비추 합니다 . 그래도 편하 긴 하 네요 .',
#  'negative\t%^^ × ? × ^ × &#*,>,;// × &>>*(*^%= ÷ #~^&,*)',
#  "negative\t' 0 -'] - 0 ] - '- - 0 o -",
#  "negative\t' KF 94 이지 숨 마스크 ' 인 줄 알 고 저렴 하 여 구매 했 는데 배송 된 것 은 완전히 다릅니다 . 중국 의 ' KAYLEINSTER ' 회사 제품 이 며 , 3 층막 으로 된 ' 비 의료 ' 용 입니다 . 대충 가격 으로 봐서 그런 줄 알 고 샀 으니 ' 구매 확정 ' 은 했 습니다 . 쓰 느냐 안 쓰 느냐 그것 이 문제 입니다 !",
#  "negative\t' 듀퐁 골드 ' 구매 했 는데 . . 골드 가 아니 라 X 색 이 네요 . ㅠ . ㅠ 사진 으로 만 봤 을 땐 약간 의 광택 이 있 고 화려 하 리라 생각 했 는데 . . 그렇 지 않 고 완전 텁텁 한 X 색 . .. 이사 하 고 나 서 집들이 손 님 맞이 용 으로 구매 한 거 라 교환 할 시간 도 없 고 해서 그냥 달 았 습니다 . 커튼 설치 는 신랑 이 한 거 라서 쉽 게 했 고요 . 다른 분 리플 과 는 달리 부품 은 여분 으로 많이 주 셔서 남 았 습니다 . 여분 으로 여러 개 온 것 도 모르 고 커튼 봉 에 죄다 넣 어 놔서 놀 고 있 는 부품 들 이 있 네요 . 다시 달 려고 하 니 신랑 이 귀찮 아 해서 포기 . . --; 암막 커튼 으로서 의 기능 은 확실 하 네요 . 한 낮 에 도 햇빛 하나 안 들어오 네요 . ㅋ 너무 어두워서 낮 엔 속 커튼 만 쳐 놓 고 있 어요 . 커튼 천 도 두꺼워서 바람막이 역할 도 확실히 하 네요 . 참고 로 사실 때 가로 x 세로 길 이 확실히 보 시 고 사 시 길 . . 전 가로 길이 만 생각 하 고 세로 길이 를 미처 생각 못 했 거든요 . 달 고 보 니 많이 모자라 네요 . 이런 실수 저 만 하 는 건가 . .? ^^;",
#  "negative\t' 배송 빠르 고 가격 저렴 해서 좋 은데 벨트 고리 가 기존 거와 반대 라 불편 하 네요 ' 라고 처음 리뷰 를 달 았 는데 실제 사용 해 보 니 아주 많이 , 정말 많이 불편 하 네요 . 왼손잡이 면 편할 지 모르 겠 지만 . - 아무리 생각 해도 이건 불량품 인 것 같 네요 . : 비록 돈 은 얼마 되 지 않 지만 처음 제품 을 반품 했어야 했 다는 생각 과 이건 정말 아니 다 라는 후기 를 달 았 어야 했 다는 생각 이 드 네요 . 그것 도 많이 .",
#  "negative\t' 상품 준비 중 ' 이 면 결제 취소 가능 한 것 아닌가요 ? 확인 후 에 취소 한 건데 ' 판매자 취소 거부 '? 로 배송 이 되 었 네요 . 작 은 금액 이 지만 기분 은 좋 지 않 군요",
#  "negative\t' 비타 500 ' 100 개 ( = 10 개 × 10 박스 ) 를 주문 해서 주변 사람 들 에게 선물 로 나눠 주 려고 했 는데 . . 2 개 가 깨져서 모든 박스 가 다 젖 었 습니다 . 이 상태 로 는 선물 도 못하 는데 . . 참 아쉽 네요 . .",
#  "negative\t' 아기 가 자 고 있 어요 ' 사은품 은 누락 되 어 왔 네요 ㅡㅡ",
#  'negative\t( ( ( ( ( ( ( ( ( ( (',
#  "negative\t( ;';'(;';'' / ; * . ' ; ' ( . ' ; ' ' ( ; = ♤ < = ♤ > ☆ > % ☆ > \\ ☆ > % ☆ > % ☆ > % ☆ > % ☆ > \\ □ ○ ※ ￡ ● 《 ￡ $ 《 ￥ $ 《 ￡ ● ※ ￡ $ 《 ￡ $ ￡$《￥$《￡●《￡$《￡●《《$《《￡《￡$《《",
#  'negative\t( NEW ) 하수구 냄새 차단 트랩 하수구 / 싱크대 / 세면대 / 세탁기 냄새 차단 ! ! 하수구 트랩 싱크대 배수구 씽크 대배 수구 냄새 는 어느 정도 차단 되 는 듯 하 나 . . 작 은 날파리 들 은 올라오 네요 --',
#  'negative\t( 수정 ) 자석 처럼 짝 달라 붙 는 정도 는 아니 어도 고정 될 만큼 붙 네요 . 신기 헙니다 . 케이스 낀 상태 로 거치 할 수 있 어서 좋 아요 -> 붙일 때 신경 써야 하 고 신경 안 쓰 면 떨어집니다 . 시간 지나 서 먼지 붙 고 나 니 붙 지 도 않 네요 . 매번 닦 아서 쓸 수고 없 고 . . 편하 려고 산 거 치댄 데 . . 결국 자석 형 을 하나 더 샀 습니다 .',
#  'negative\t( 지극히 개인 적 인 후기 ) 색은 차콜 로 했 지만 갈색 이 나오 는 거 같 고 이건 사람 피부색 에 따라 다를 거 같 고 저 는 괜찮 아서 색 은 참 마음 에 드 는데 아무리 유분 기 가 있 게 해서 그려 주 어도 눈썹 이 있 는 살 ( 피부 ) 만 아프 지 정말 잘 그려지 지 않 아요 ㅜㅜ제가 똥 손 이 어서 그런 거 라 생각 하 려 했 는데 아니 에요 ㅠㅠㅠㅠ진짜 그리 고 싶 어도 잘 안 나와서 못 그려요 ㅠㅠ 꾹꾹 눌러서 그려 주 면 나오 기 야 나오 는데 피부 가 너무 아파서 . .. 후 ㅠㅠ삐아 다른 색조 화장품 이나 아이라이너 쪽 은 너무 만족 해서 이것 또한 기대 하 고 구매 한 거 였 는데 그냥 갈색 색연필 로 쓰 려구요 ㅠㅠ허허 . .',
#  'negative\t( 착용 전 ) 제 가 구매 한 스타킹 엄청 보들보들 하 고 살 비침 이 거의 없 어서 완 젼 좋 아요 ~~!! ( 착용 후 수정 후기 ) 스타킹 이 줄줄 내려가 서 골반 에 간당간당 걸쳐 있 어요 . . 후 . . 덜 쫀쫀 하 다는 거 겠 죠 ? 하루 종일 스타킹 올리 느라 엄청 신경 쓰였 네요 ㅠ',
#  'negative\t( 사용 전 ) 이 십 년 이상 사용 중 인 오 랄 비 전동 칫솔 . 전동 칫솔 은 오 랄 비 가 가장 만족 스럽 습니다 . 기존 에 쓰 던 게 낡 아서 새로 구입 했 는데 금번 제품 이 가성 비 갑 인듯 . ( 사용 후 ) 기존 부 가 기능 이 많 은 고 사양 제품 사용 중 항상 기본 기능 만 사용 해서 기본 형 만 장착 된 실속 형 제품 을 구입 했 는데 뭔가 그간 사용 하 던 제품 의 품질 이 아닌 것 같 습니다 . 혹시 생산 원가 절감 을 위해 무엇 을 하 셨 나요 ? 사진 은 왼쪽 이 기존 에 사용 하 던 충전기 , 오른쪽 이 새로 구입 한 충전기 입니다 . 바닥 스토퍼 기능 을 하 는 까만색 부품 이 없 어 져 세면대 위 에서 춤 을 추 네요 . 전기선 도 조금 더 길 게 생산 하 면 안 되 나요 ? 너무 짧 아서 설치 장소 가 제한 적 입니다 .',
#  'negative\t( 예전 리뷰 다시 수정 합니다 . ) 산지 일 주일 도 안 돼서 20 cm 높이 쯤 에서 놓치 게 됐 는데 금 갔 어요 바닥 에 떨어뜨린 것 도 아니 고 차안 에서 요 . 여기 리뷰 수 많 은 이유 는 모두 1 + 1 이벤트 때문 이 네요 강화 유리 커버 여러 곳 꺼 써 봤 지만 이렇게 고가 이 면서 단번 에 망가지 는 건 처음 이 에요 품질 에 대해 온갖 내용 으로 광고 해서 믿 고 샀 는데 정말 실망 하 고 다시 는 여기 서 안사 요 . 딱 사기 당한 기분 .',
#  'negative\t( 광목 패치 퍼플 . 블루 ; 화면 색상 과 달라도 너무나 다르 고 선명 하 지 않 고 빛바랜 색상 이 네요 . . 커버 두께 는 몇 번 빨 면 다 헤 질 듯이 얇 고 요즘 솜 도 압축 으로 보내 던데 통 으로 보내 서 두께 가 ;;',
#  'negative\t( 안감 처리 ) 속주머니 가 안 되 있 네요 . ㅠㅠ',
#  'negative\t( 행사 특가 ) 라는 표시 는 없애 시 는 게 좋 을 듯 . . 점점 가격 이 내려감 ( 행사 특가 ) 라는 표시 는 없애 시 는 게 좋 을 듯 . . 점점 가격 이 내려감 ( 행사 특가 ) 라는 표시 는 없애 시 는 게 좋 을 듯 . . 점점 가격 이 내려감 ( 행사 특가 ) 라는 표시 는 없애 시 는 게 좋 을 듯 . . 점점 가격 이 내려감 ( 행사 특가 ) 라는 표시 는 없애 시 는 게 좋 을 듯 . . 점점 가격 이 내려감 ( 행사 특가 ) 라는 표시 는 없애 시 는 게 좋 을 듯 . . 점점 가격 이 내려감 ( 행사 특가 ) 라는 표시 는 없애 시 는 게 좋 을 듯 . . 점점 가격 이 내려감 ( 행사 특가 ) 라는 표시 는 없애 시 는 게 좋 을 듯 . . 점점 가격 이 내려감 ( 행사 특가 ) 라는 표시 는 없애 시 는 게 좋 을 듯 . . 점점 가격 이 내려감 ( 행사 특가 ) 라는 표시 는 없애 시 는 게 좋 을 듯 . . 점점 가격 이 내려감',
#  'negative\t( 행사 특가 ) 페리오 치약 150 g x 20 개 청 은 차 애경 2080 송염 메디안 치석 충치 입 냄새 제거 구취 기능 성 B 상품 선택 : 45 강력 한 스 크 럽 x 4 + 촉촉 한 겔 x 4',
#  'negative\t( 당일 출고 / 무료 배송 ) 야구 모자 / 볼 캡 / 캠프 캡 / 스냅 백 / 남자 / 여자 / 모자 / 베이스볼 캡 11 , 900 원 [ 옵션 ] 옵션 선택 : C 02 _ 롱 챙 무지 볼 캡 / 색상 : 검정 - 1 개 ( + 400 모자 가 삐뚤 어 짐 .',
#  'negative\t( 구매 자분 들 꼭 필독 해 주 시 기 바람 사진 까지 첨부 함 ) 고객 을 호구 로 아시나 보네 상품 을 제대로 보내 지 도 않 는 곳 은 다음 에 구매 하 는 분 들 한테 폐 만 끼칩니다 . 내용 은 이렇 습니다 . 블랙 바지 와 그레이 바지 를 사진 에 있 는 모양 으로 하나 씩 구매 를 해서 받 았 는데 블랙 바지 는 제대로 검토 도 안 하 고 전혀 다른 걸 같이 보냈 네요 . 일 때문 에 라도 교체 나 환불 할 수 있 는 시간 도 안 되 서 다시 보내 봐야 또 기다려야 할 것 같 고 . ..',
#  'negative\t( 구매 자분 들 꼭 필독 해 주 시 기 바람 ) 고객 을 호구 로 아시나 보네 상품 을 제대로 보내 지 도 않 는 곳 은 다음 에 구매 하 는 분 들 한테 폐 만 끼칩니다 . 내용 블랙 바지 와 그레이 바지 를 사진 에 있 는 모양 으로 하나 씩 구매 를 해서 받 았 는데 블랙 바지 는 제대로 검토 도 안 하 고 같이 보냈 네요 일 때문 에 라도 교체 나 환불 할 수 있 는 시간 도 안 되 서 다시 보내 봐야 또 기다려야 할 것 같 고 . .. 글 만 작성 되 서 올라가 면 사진 찍 어서 다시 올립니다 .',
#  'negative\t* 285 특수 주문 으로 했 는데 . .. 제품 사이즈 를 보 니까 280 하 고 동일 합니다 . 결국 5 미리 작 게 나왔 는데 . .. 반송 하 기 도 그렇 고 늘려서 신 어야 할 듯 싶 네요 ~ 제품 품질 은 만족 하 는 수준 이 고 가격 대비 에 는 약간 비싼 듯 보입니다 . 다음 에 290 을 주문 해야 할지 . .. 사이즈 를 자체 적 으로 증대 할 껀 지 . .. 알 수 가 없 네요 ~',
#  'negative\t* 저 는 엘 모린 을 구입 했 지만 페니 슈 상품 에 대한 리뷰 임 을 알려 드립니다 일단 제 구입 시기 는 작년 여름 입니다 . 친구 는 올해 도 한 켤레 구입 했 고요 . 워낙 쪼 리 를 좋아하 기 도 하 고 , 사뿐 자체 제작 이 라고 너 ~ 무 자신감 이 넘치 시 길래 믿 고 제 꺼 4 개 , 친구 꺼 2 개 총 6 켤레 나 구입 했 어요 . 결과 는 요 ? 모든 신발 이 전부 사진 과 같이 됐 습니다 . 심지어 친구 가 구매 한 상품 중 하나 는 올해 구입 한 건데 도 벌써 저렇게 벌어지 네요 ~ 그냥 한두 개 는 싸 니까 그러 려니 하 려 했 는데 6 켤레 가 전부 그러 는 건 너무 심하 지 않 나요 ? ㅋㅋ 더 어이없 는 건 사진 에 있 는 신발 이 5 번 도 안 신 은 신발 이 라는 점 이 에요 . . 제 가 신발 로 망치질 을 한 것 도 아니 고 , 5 번 도 안 신 었 는데 착화 습관 에 따라 떨어질 수 있 다고 하 시 면 . . 음 할 말 이 없 네요 ㅎㅎ 사뿐 에서 앞 으로 쪼 리 살 일 은 절대 없 을 거 같 긴 한데 , 인 스타 그램 보 다가 좀 웃겨서 요 ㅋㅋ 절대 따라 올 수 없 는 퀄리티 는 사 뿐 의 프라이드 . .? 사뿐 의 프라이드 는 겨우 이 정도 인가 보 네요 . .',
#  'negative\t* 뇌진탕 주의 : 물 에 젖 으면 심하 게 미끄러워 요 . 이 신 사고 일 주일 정도 지났 는데 벌써 여러 번 넘어질 뻔 했 습니다 . 갑자기 폭우 내리 는 이런 장마 날씨 에 는 안 신 는 게 좋 을 듯 합니다 . 물 에 젖 은 이 신 을 신 는 것 보다 신발 을 벗 고 바닥 의 유리 던 파편 이 던 다른 위험 을 맞닥뜨리 는 게 더 안 전합니다 . 신 은 만만 하 게 신기 에 좋 은데 발가락 에 거 는 부분 비올 때 특히 오르막길 올라가 면 엄청 미끄러져서 빠지 는데 그 거 는 부분 이 신발 이 안 빠져나가 게 막 고 있 는 역할 이 라 빠져 버리 면 사정 없이 미끄러지 고 신발 자체 가 발바닥 면 에서 벗어납니다 . 걸 을 수 없 는 상태 가 돼요 . 다치 실 수 도 있 으니 이 점 유의 하 셔야 할 것 같 아요 . 신발 자체 는 무난 하 게 어디 에 나 잘 어울려요 . 물 기 라곤 없 는 바 싹 마른 날 에 신 으시 는 걸 추천 드려요 .',
#  'negative\t* 아주 아주 마음 에 쏙쏙 듭니다 . 판매자 님 대응 마음 에 들 어요 . 앞 으로 도 자주 구매 원 합니다 . 번창 하 세요 . 고맙 습니다 . 복 받 으실 거 에요 . 별로 입니다 . 너무 얇 네요 .',
#  'negative\t* 전반 적 인 배송 포장 상태 는 좋 았 습니다 . 그러나 , 여러 겹 비닐 포장 을 뜯 고 나 서 물건 상태 를 보 니 조금 더 신경 을 쓰 셔야 하 지 않 을까 합니다 . ( 1 ) 블라인더 한쪽 이 무언가 에 찍혀서 푹 눌려 있 습니다 . ( 2 ) 물건 포장 전 에 어디 에 긁힌 것 인지 검정 색 도료 가 묻 어 있 습니다 . ( 3 ) 검정 도료 만 묻 은 게 아니 라 심하 게 끌 었 는지 아예 하얀 페인트 도 벗겨져 있 습니다 . 올해 봄 되 면서 전 에 구입 했 다가 만족 해서 다시 구매 하 는 것 인데 , 물건 상태 보 고 좀 실망 했 어요 . 물건 은 일 년 남짓 사용 해 보 니 만족 인데 , 포장 과정 에서 물건 이 하 자 난 것 을 그냥 보내 주 시 니 좀 어 이 가 없 네요 . 여기 에서 주문 하 시 는 분 들 이 거의 실측 주문 제작 이 라고 해도 이번 것 하 자는 조금 아닌 듯 합니다 . 구입 예정 이 신 분 들 과 구입 하 신 분 들 도 꼼꼼히 체크 해 보 세요 .',
#  'negative\t* 상품 설명 이 부족 , 아쉬움',
#  'negative\t* 정 사이즈 가 왜 이리 작 나요 . ..',
#  'negative\t* 가방 사이즈 가 작 으니 주 의 요망',
#  'negative\t* 물건 받 은 후 물건 잘 포장 되 어서 배송 되 었 네요 판매자 님 의 새 다른 공 1 개 넣 어 주 시 는 센스 ^^ 감사 합니다 * 사용 후기 실망 스러웠 습니다 골프 입문 한지 1 년 도 안 되 다 보 니 로스트 볼 을 사용 하 게 되 었 고 그 중 그래도 이뻐 보이 고 이름 있 는 타이틀 리스트 축구공 문양 받 고 나 서 기분 좋 았 지요 . 공 받 고 라운 딩 가 서 사용 하 는 데 일행 및 캐디 . .. 10 개 가져갔 는데 이런 절반 이 짝퉁 . .. 로스트 볼 치고 고가 라 생각 하 여 안 그럴 줄 알 았 는데 . .. 저 처럼 모르 는 하수 들 은 봉 ? 남 은 20 개 . .. 어찌 해야할까 고민 스럽 네요 . ..',
#  "negative\t* 최악 이 라 해야할까 * * 요약 * -- 주문 받 으면 블라인드 제작 , 배송 도 하 지 않 고 송장 부터 올려서 고객 을 꼼짝 못 하 게 함 . .. 사랑 에 빠질 판 . ... -- 공장 에서 직접 수령 하 면 ' 구매 확정 ' 을 해야 가져갈 수 있 다는 정신 나간 소리 를 합니다 * 결론 * -- 월요일 주문 하 고 금요일 전화 하 니 이제 제작 하 고 있 다 . .. 주문 에서 배송 까지 기본 월화수 목금 토 6 일 걸립니다 , 바쁘 신 분 들 은 다른 블라인드 로 고고 싱 * 본문 * 월요일 주문 하 니 화요일 송장 번호 가 나옵니다 기다리 다 목요일 전화 하 니 아직 제작 안 했 답니다 그럼 송장 은 왜 올리 냐니까 원래 주문 받 으면 송장 부터 올린다 네요 . 일단 송장 은 바로 올리 고 제작 도 배송 도 안 합니다 . 일단 송장 등록 되 면 컴 터 나 폰 으로 는 취소 불 가능 한 거 아 시 죠 ? 전화 로 취소 해 달 라 요청 해야 합니다 . 이걸 노린 거 같 네요 , 그런데 전화 하 면 거의 항상 통화 중 이 라는 게 함정 . . 일단 고객 잡 아 놓 고 일 은 느긋 하 게 하 려는 재 치 있 는 사람 들 이 죠 , 그 다음 , 급 해서 직접 받 으러 가 기 로 했 습니다 판매자 정보 에 나오 는 주소 는 위장 ? 입니다 ㅋ 교회 에 도착 함 . ... 다시 공장 찾아가 서 물건 받 아 나오 려니 신기 한 소리 가 들립니다 . 제품 을 직접 수령 하 면 그 자리 에서 구매 확정 을 해야 가져갈 수 있 다고 윽박지르 십니다 . 물건 을 확인 도 안 했 는데 구매 확정 을 안 하 면 공장 에 잡 아 둘 기세 입니다 . 앞뒤 가 맞 냐고 따져 물으니 그냥 그렇 다고 함 . .. 장사 꾼 이 되 어야지 , 장사치 는 되 지 말 자 . .",
#  'negative\t* 필름 사 지 마세요 * 케이스 는 아무 문제 없 습니다 만 같이 시킨 지문 방지 필름 이 문제 네요 . 사진 과 같이 터무니 없이 작 습니다 . 엣지 제외 제품 이 라고 써져 있 기 에 정상 제품 이 라고 하 시 는 데 엣 지만 제외 된 게 아닌데요 ? 핸드폰 액정 의 1 / 3 이 텅텅 빕 니다 . 이게 정상 적 이 라고 생각 하 시 는 분 만 구매 하 시 길 . 일부러 악 성 재고 끼워 팔 고 반품 하 기 애매 하 게 만들 어서 처분 하 는 행태 라고 밖 에 보이 지 않 습니다 . 필름 부분 에 도 사진 게제 하 고 제품 설명 명확히 해 주 십시오 .',
#  'negative\t* 동영상 27 초 에 현상 이 제일 잘 보입니다 * 봉지 안쪽 에 정전기 가 일어나 서 그런지 모르 겠 는데 수저 를 뜨 면 자석 에 쇳가루 붙 는 것 처럼 떠지 는데 인터넷 에 중금속 이야기 나오 던데 이게 왜 그런 건지요 ( 가루 에 수저 를 많이 휘저 을수록 많이 붙 네요 ) 건강 하 자고 산 건데 무섭 네요 환불 요청 드립니다 연락 꼭 주세요 허브 나래 홈페이지 에 헤럴드 경제 랑 어떤 신문사 에 제주 팜 스친 환경 영농 조합 새싹 보리 에 중금속 나왔 는데 아닌 걸로 판명 나 서 기사 정정 까지 하 셔서 믿 고 구매 했 는데 불안 합니다 ( 허브 나래 홈페이지 글 캡쳐 해서 올릴 려고 했 는데 지금 은 내려갔 네요 ) 이게 뭔지 설명 좀 부탁 드리 고 환불 처리 요청 합니다',
#  'negative\t* 판매자 야 리모컨 가지 고 장난치 지 말 고 빨리 보내 주 라 * LG 배송 설치 기사 님 친절 함 은 최고 네요 더운 날씨 에 도 웃 으시 면서 친절히 설명 잘 해 주 시 고 티비 또한 깔끔 한 디자인 에 인터넷 까지 가능 하 니 두말 할 게 없이 좋 아요 공주 님 들 테 블릿 으로 유 툽 봤 는데 이젠 티비 큰 화면 으로 볼 수 있 어 엄청 좋 아 하 네요',
#  'negative\t* 별로 긴한 데 터치 민 감도 를 높이 니 그나마 눌러 는 져요 ! !',
#  'negative\t* 상품 이 엉성 함 Plastic Pad 는 11 개 가 아니 고 2 개 만 발송 됨',
#  'negative\t* 샌달 귀 판매 업체 에서 3 켤레 다른 모델 로 구매 했 어요 , 신 고나서 알 았 습니다 . 샌달 가격 이 싼 게 아니 라 좋 다고 구매 했 는데 , 신어 보고 좀 걸 었 는데 좌측 우측 발가락 엄지발가락 옆 두 군데 피부 가 벗겨져 약 바르 고 대일 밴드 붙이 고 난리 가 아닙니다 . 왜 타 샌 달 보다 비싸 게 팔 면서 발 에 도 맞 지 않 는 샌달 판매 하 시 는지요 . 그렇게 판매 한다면 좋 으시 겠 는지요 . 도대체 왜 발가락 좌우 측 피부 가 벗겨지 는지 샌 달 제대로 만든 것 판매 하 시 기 바랍니다 .',
#  'negative\t* 샌달 귀 판매 업체 에서 3 켤레 다른 모델 로 구매 했 어요 , 신 고나서 알 았 습니다 . 샌달 가격 이 싼 게 아니 라 좋 다고 구매 했 는데 , 신어 보고 좀 걸 었 는데 좌측 우측 발가락 엄지발가락 옆 두 군데 피부 가 벗겨져 약 바르 고 대일 밴드 붙이 고 난리 가 아닙니다 . 왜 타 샌 달 보다 비싸 게 팔 면서 발 에 도 맞 지 않 는 샌달 판매 하 시 는지요 . 그렇게 판매 한다면 좋 으시 겠 는지요 . 도대체 왜 발가락 좌우 측 피부 가 벗겨지 는지 샌 달 제대로 만든 것 판매 하 시 기 바랍니다 . * 사이트 에 클레임 재기 귀 업체 판매 하 는 샌달 문제 가 있 다고 하 겠 습니다 . 샌 달 은 발 이 편 해야지 몇 분 걸 었 다고 발가락 피부 가 벗겨지 면 누가 귀 업체 샌달 은 구매 해서 신 겠 는지요 .',
#  'negative\t* 상품 사진 처럼 넉넉 한 사이즈 아니 네요 . 끈 이 . . 그냥 케이크 장식 리본 보다 거친 ? ! ㅡㅡ 끈 으로 쓰 기 에 는 알맞 지 않 은 리본 이 라 . . 그 부분 이 좀 실망 이 네요 . 묶 으니 거칠 어서 목 이 따가워 요 . 끈 을 교체 해서 써야 겠 어요 . * 배송 빠릅니다 ~',
#  "negative\t* 오염 ( 파란색 염료 ) 바닥 부분 에 파란색 염료 까지 묻 어 있 습니다 . 아래 사진 의 파란색 얼룩 ( ? ) 은 커튼 과 바닥 이 맞닿 는 부분 인데 , 파란색 이 왜 묻 었 는지 모르 겠 어요 . 아직 세탁 하 지 않 아서 지워 질지 안 지워 질지 모르 겠 어요 . 커튼 바닥 부분 이 라 별로 신경 은 안 써도 될 듯 하 지만 , 그래도 상품 받 자마자 저렇게 색 이 묻 어 있 어서 기분 이 좋 지 는 않 았 습니다 . * 1 폭 을 2 장 씩 이어 박 음 4 폭 주문 했 습니다 . 커튼 천 을 2 폭 너비 로 통 으로 잘라 2 장 으로 만들 어야 하 지 않 나요 ? 그런데 이 1 폭 너비 천 을 2 장 씩 이어 박 아서 2 장 을 보내 주 셨 습니다 . 색상 이 ' 화이트 ' 라고 써 있 었 는데 , 실제 색상 은 밝 은 회색 입니다 . 헤링본 무늬 가 잔잔 하 게 들어가 있 어요 .",
#  'negative\t* 추가 * 이거 신고 퇴근 하 다가 계단 에서 미끌 어 넘어졌 습니다 굽 이 덜렁거리 네요 발등 다 까졌 구요 . 처음 신 은 날 바로 발목 날아갈 뻔 했 네요 . 미끄러우 니까 감안 하 고 신고 사세요 신발 은 이쁜데 한 사이즈 업 해서 사도 발 에 물집 잡히 는 건 어쩔 수 없 나 봐요 ㅠ 아침 에 출근 할 때 30 분 신 었 는데 발가락 에 물집 잡혀서 너무 아파요',
#  'negative\t* 플 러 * 에서 다른 제품 을 사만 원 대 에 1 + 1 에 팔 더라구요 기능 이 별로 없 는 건 마찬가지 던데 . .. 너무 비싸 게 산 거 같 아 속상하 네요',
#  'negative\t* 장점 - 미니 사이즈 : 공간 을 많이 차지 하 지 않 아 효율 이 좋 습니다 . * 단점 - 기존 갑 티슈 와 비교 했 을 때 사이즈 자체 가 작 다 보 니 아무래도 더 얇 게 느껴 지 는 것 같 아요 - 얇 다 보 니 톡 뽑 아 쓸 때 뒷 휴지 가 따라 안 올라와서 새로 뽑 을 때 손 을 집어넣 어 꺼내 게 되 더라구요 ㅠㅠ',
#  'negative\t* 사이즈 ㅡ 최악 이 에요 ! !! 저 는 원래 신발 사이즈 235 m 를 신 는데 240 m 로 시켰 더니 넘 나 작 아서 다시 245 m 교환 했 더니 , 이번 엔 넘 나 큰 게 왔 네 욧 ! !! 헐 ㅡㅡㅡㅡ 대체 무슨 사이즈 를 신 으라는 건지 . .... ㅠ ㅠ 사이즈 개 엉망 임 . * 착용감 ㅡ한번신고 발 뒷 꿈 치 까졌 구 욧 ! !! * 서비스 ㅡ판매자는 일 주일 넘 게 저 나 를 당 췌 안 받 아 욧 ! ! 이상 한 회사 얌 . .... @@ * 신발 사이즈 는 최악 이 구 욧 서비스 는 엉망 입니다 @ 다시 는 이런 데 서 신발 안 살 랍니다 ㅡㅡ ㅠ ㅠ',
#  'negative\t* 상품 이 엉성 함 동일 불만 내용 임 그냥 사용 예정',
#  'negative\t* 상품 이 너무너무 약해요 . 시장바구니 로 는 못 쓸 것 같 습니다 .',
#  'negative\t* 마트 에서 더 싸 게 팔 더라고요 ㅠㅠ . 무료 배송 이 라고 해서 그냥 속상한 마음 접 었 습니다 . ..',
#  'negative\t* 수고 하 십니다 . 제품 손잡이 가 생각 보다 너무 약해 사용 하 기 가 불편 합니다 .',
#  'negative\t+ 5 일 됐 는데 와 진심 살짝 한번 툭 떨어뜨렸 는데 바로 금가 네요 . .. 비싼 값 너무 못 하 는 듯 ;;; 에 반데요 ? 원래 잘 이렇게 잘 깨지 나 . .. ㄹ ㅇ 강화 유리 맞 나요 ? ? 강화 실패 하 신 거 아니 에요 ?',
#  'negative\t+ 무 염산 친환경 해 남김 + 2013 년 2 월 햇김 / 지주식 김 / 최상품 특파 래 김 / 재래 김 / 재래 돌김 / 생산자 직송 판매 3 , 300 말 만 햇김 이 고 완 점 뻘건 묵 은 김 입니다 . 구워도 파란색 하나 없이 갈색 이 고 바고 쭈굴해지며 구워 집니다 .',
#  'negative\t+) 판매 만 하 면 끝 입니다 . 2 달 을 기다려도 준다던 상품권 도 안 주 고 알아보 고 연락 준다고 하 더니 전화 도 없 습니다 . 전 에 회사 에서 쓰 던 웅진 이나 청호 는 고객 센터 겁나 친절 하 고 빨랐 는데 쿠쿠 는 아주 답 이 없 네요 . 친절 은 판매 상 담사 실적 올릴 때 만 나오 고 그 외 는 나 몰라라 네요 . 해지 할 겁니다 . -- 짜증 나 네요 . 상담원 하 고 통화 할 때 14 만 원 이 라고 안 내받 았 는데 12 만 원 만 왔 더라구요 . 리뷰 이벤트 상품권 도 안 오 구요 . 그래서 고객 센터 에 전화 했 더니 상품 페이지 에 도 12 만 원 이 라고 되 어 있 다고 안 준대요 . 그래서 상품 페이지 중간 에 변경 되 었 고 녹취 확인 하 시 라니까 녹취 가 없 대요 . 얼척 이 없 어서 . -_- 하지만 요새 폰 좋 잖아요 . 잔 자동 녹음 기능 켜 두 는 편 이 라 녹취 있 다니까 그제서야 3 만 원 마지못해 준다는 듯이 준대요 . 하 ~ ㅎㅎ . 그것 도 이번 달 말일 에 ㅋㅋ ㅋㅋ 어차피 지금 급하 게 쓸 일 도 없 어서 그러 라고 했 는데 . ( 지금 주 면 안 된다 냐니까 상담원 이 자기 는 담당자 가 지시 사항 을 전달 하 는 것 뿐 이 래요 ㅋㅋ 제 지금 직장 이 콜 센터 끼 고 있 는 곳 이 라 상담원 들 고충 을 알 아서 별말 안 함 . ㅋㅋㅋ ) 설치 기사 님 와서 설치 까지 만 딱 좋 구요 . 리뷰 이벤트 부터 내리 최악 임 ㅋㅋㅋ ㅋㅋ 이걸 5 년 이나 더 써야 한다니 바꾸 는 거 귀찮 아서 5 년 만 쓰 고 이제 쿠쿠 는 손절 할려구요 . ㅋㅋ ㅋㅋ 아 놔 리뷰 이벤트 그래도 좋 게 썼 는데 내 가 미 ㅊ * 이 지 ㅋㅋㅋ ㅋㅋ 다 들 녹취 키 고 상담 받 으세요 ~~~ -- 정수기 직수 형 으로 바꾸 고 싶 은데 디자인 이 영 ~~ 마음 에 드 는 게 없 더라구요 . 근데 쿠쿠 는 디자이너 가 열 일 하 시 는 거 같 아요 ~. 디자인 도 색상 도 너무너무 이뻐요 ~~ ( 솔직히 성능 이딴 거 보다 이뻐서 골랐 음 ) 직수 형 이 라 출수 속도 가 너무 느려서 답답 헌데 . .. ( 컵라면 못 먹 겠 네요 ) 물탱크 가 있 는 것 보단 위생 적 이 니까요 . 만족 합니다 ~',
#  'negative\t+/- 잘못 꽂 았 다가 노트북 USB 쪽 보드 날 아감 구분 을 직관 적 으로 하 기 쉽 지 않 게 만들 어서 문제 가 많 음',
#  'negative\t+ 0 * 생각 이상 으로 광택 이 . . 남자 사용 불가 품목 은 듯 , ㅠ , ㅠ',
#  'negative\t+ 7500 원 옵션 질 . ..',
#  'negative\t+ 9988776 ㅣ 65535367299202010',
#  'negative\t+ 단자 쪽 이 너무 판판 해서 수입 산 후레쉬 등 . . 안 맞 을 우려 가 있 습니다 , 제 경우 도 국내 산 제품 엔 맞 는데 이 글 택 ( 미국 산 ) 은 닿 질 않 아 사용 을 못 합니다 , 회원 님 들 꼭 숙지 하 시 길 ~',
#  'negative\t,',
#  'negative\t, , ㄱ ㄴ ㄷ ㄹ',
#  'negative\t, . .',
#  'negative\t, ,',
#  'negative\t, , 사진 이랑 완전 다른 물건 왔 어요 ㅡ . ㅡ 디자인 훨씬 구림 . ..',
#  'negative\t, , , , , , , , , ,',
#  'negative\t, , , , , , , , , , , , , , , , , , , , , , , , , , , , , ,,,,,,,,,,,,,,,,,,,,,,,,,',
#  'negative\t, , , , 귀걸이 한 쌍 중 에 한 짝 이 큐빅 ? > 빠져 있 는 상태 로 왔 네요 , .,, ㅡㅡ 어차피 . .. 한 쪽 만 쓸 거 긴 하 지만 . .. 이런 거 확인 도 안 하 고 보내 시 나요 ? >?? 확인 좀 잘 하 시 고 판매 하 시 길 ! !!!',
#  'negative\t, 5 개 중 에 2 개 불량 1 개 반품 신청 후 응답 없 고 다른 1 개 도 사용 하 려고 보 니 불량 플러그 가 ? 혀 지 지 않 음',
#  'negative\t, ???????????????',
#  'negative\t, qi , ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ? ?????????????????????????',
#  'negative\t, 너무 허접 해서 버려야 돼요 . 반품 비 아까워 . 버림',
#  'negative\t, 배송 도 빠르 고 다 좋 은데 담배 가 케이스 안 에서 막 돌아다녀서 뚜껑 닫 을 때 마다 가지런히 정리 해야 하 는 번거 로움 이 있 네요',
#  'negative\t, 놀이 장난감 ? 막대기 가 썩 었 어요 시커멓 게 곰팡 이 같 은데 확인 도 안 하 시 나 봐요 구매 안 하 는 게 좋 을 꺼 같 아요',
#  'negative\t, 그냥저냥 그렇 코 그냥 배송 도 대따 불 만족 . .. 그냥 그렇 네요',
#  'negative\t-',
#  'negative\t- -- -- -- -- -- -- -- --',
#  'negative\t- 리뷰 수정 - ● 한 해 여름 밖에 사용 못 해요 . 좀 사용 하 다 보 면 폴 대 끝 의 네 플라스틱 에 균열 이 생기 고 , 부러지 고 , 급기야 뜯 어 지 기 도 합니다 . 플라스틱 경도 가 낮 아요 . * 플라스틱 받침대 흰 끈 이 뜯 어 졌 음 * 플라스틱 받침대 가 자주 빠짐 * - 최초 리뷰 - 내내 생각 만 하 다가 드디어 장만 했 어요 . 이젠 극성 스러울 모기 걱정 하 지 않 아도 되 겠 어요 . 이 방 저 방 , 방방이 구입 하 면 좋 겠 더군요 . ^^ * 200 × 180 이 3 ~ 4 인용 이 라지만 넉넉 한 2 인용 이 라 보 시 면 됩니다 . 바닥 면적 이 여유 로우 면 큰 것 으로 사세요 * 세로 지퍼 가 위 까지 더 열리 면 출입 하 기 더 쉬울 거 같 아요 . * 펼치 고 접 을 때 끼 고 빼 고 하 는 플라스틱 양쪽 이 부러지 지기 쉬워 보여요 . 조심조심 . .. ㅠ *',
#  'negative\t- 처음 받 았 을 때 느낌 : 와 디자인 굿 , 가격 굿 , 배송 굿 이 야 득템 했 다 한 벌 더 살까 너무너무 좋 아 했 다 - 처음 입 었 을 때 느낌 : 내 몸 에 너무 딱 맞 아 굿 촉감 좋 아 굿 , 따뜻 해 너무 좋 아 굿 - 입 은지 몇 시간 이 지났 을 때 : 어디 서 자꾸 털 이 빠지 지 ? 검정 색 솜 같 은 게 자꾸 빠지 네 한번 빨 아 입 으면 괜찮 겠 지 지퍼 를 올리 는데 오른쪽 지퍼 가 벌어져 - 이런 썅 , 그래도 싸 니깐 이 정도 쯤 야 , 바지 주머니 는 지퍼 없 어도 별 지장 없 는데 바지 를 벗 었 는데 털 ( 안쪽 기보 솜 ) 빠져도 너무 빠져 이런 - 속옷 까지 다 시커먼 털 이 묻 어 다 버렸 네 그래도 한 번 빨 아 입 으면 괜찮 겠 지 ㅜㅜ - 바지 를 세탁 했 다 - 뒤집 어서 , 손세탁 으로 : 이런 시커먼 물 이 짝 빠지 네 , 그래도 검점 색이 니 그렇 겠 지 헹궈 도 헹구 어도 털 ( 기모 ) 가 빠져도 너 ~~~~~~ 무 빠져 , 열 번 이상 헹궈 도 빠지 네 이런 썅 ㅠㅠ 이젠 지쳐서 포기 - 세탁 하 고 처음 으로 입 었 다 : 이런 개 XX , CX 내 가 털갈이 하 는 개 도 아니 고 온 집안 에 털 을 날리 고 다닌다 . 속옷 도 엉망 , 다리 에 털 이 잔뜩 묻 었 다 -- 이젠 포기 하 고 쓰레기 통 에 버려야 겠다 --',
#  'negative\t- 바란스 장식 ( 바란스 와 는 어울리 지만 , 금새 질릴 만 한 디자인 , 싸 보이 거나 하 진 않 으나 고급 스럽 다고 생각 될 만 한 것 또한 아님 ) - 바란스 연결 부분 ( 벨 크로 - 찍찍 이 로 연결 , 봉 의 홈 에 벨 크로 가 껴서 들어가 있 는 형태 , 무지 잘 빠짐 , 끼우 는데 화남 ) - 바란스 및 본체 설치 후 전개 ( 부분 마다 쇳가루 , 까만 알 수 없 는 물질 뭍 어 있 음 , 알 수 없 는 이상 한 찌 린 내 혹은 심한 오징어 냄새 가 엄청남 , 암막 성능 은 택배 가 늦 게 와서 테스트 못 해봄 )',
#  'negative\t- 배송 은 결재 후 2 주 정도 걸림 - 모든 설치 비 24 만 원 정도 지출 - 엘리베이터 없 으면 까대 기 비용 도 추가 있 어요 참고 하 세요 ^_^ - 홈 쇼핑 보다 실제 결재 금액 이 10 - 15 차이 가 남 홈 쇼핑 은 당연히 사은품 이 있 으니 ( 필요 항 사은품 이 면 홈 쇼핑 을 추천 드립니다 ) 성능 이 는 아직 큰 불편 이 없 어서 잘 사용 합니다 와 ! !!!! 저렴 하 게 잘 샀 다는 뿌듯 함 은 잘 모르 겠 네요 ^^ 다음 가전제품 은 홈 쇼핑 에서 구매 하 려고요 ㅋㅋ',
#  'negative\t--',
#  'negative\t-- 전 믹 스핑크 랑 믹스 블랙 시켰 는데 두 개 다 믹 스핑크 로 왔 습니다 . 일부러 일 케 시킨 건데 뭡니까 이게 . ㅡㅡ 인터넷 쇼핑 이란 . .. ㅉㅉㅉㅉ',
#  'negative\t--,!,,^~??',
#  'negative\t-- 두 번 신고 밑창 덜렁거리 고 틈새 벌어지 더니 밴드 빠지 고 찢어짐 ! 똑같 은 문제 로 피해 입 은 사람 다수 ! 5000 원 왕복 택배 비 를 부담 해야 새 것 으로 교환 해 준다고 함 . 하지만 또 이러 면 ? -- ㅂ ㅐ송도 엄청 느리 구요 . . 어렵 게 받 아 신 어 보 니 착화 감 이 너무 별로 여서 며칠 고민 하 다가 수취 확인 했 어요 . 일단 여름 신발 이 가 벼 위 야 잘 신 는데 , 이건 정말 무거워 요 . 핏 플 랍 크 록스 신다 가 보세 신 어서 그런가 , 굽 이 높 은 만큼 굽 무게 가 심해요 . 그리고 바닥 이 완전히 일자 여서 걷 기 가 엄청 불편 해요 . 24700 원 이 란 가격 에 저렴 하 다면 저렴 하 고 1 . 2 만 원 보태 서 편한 브랜드 샌들 사 는 게 나을 수 도 있 는데 배송 받 는데 도 지쳤 고 . . 또 얼마나 기다려 환불 받 을까 하 는 불만 부터 생각 이 드 니 그냥 신 고 버릴까 하 는 생각 이 좀 더 큰 것 같 네요 . 단골 언니 의 샌 들 은 정말 . .. 이건 아닌 듯 합니다 . 그냥 1 . 2 만 원 보태 서 외국 브랜드 상품 사세요 .',
#  'negative\t--',
#  'negative\t-- 팸 퍼스 2 회구 입후 176 매 사용 리뷰 재 수정 . 1 회차 에 구입 한 기저귀 는 이상 이 없 었 으나 이번 에 구매 했 던 기저귀 는 . . 품질 이상 은 맞 나 봅니다 . 아이 둘 키우 면서 큰아이 는 4 살 인데 일본 제품 기저귀 입혔 었 고 이런 경우 단 한 번 도 없 었 음 . 팸 퍼스 베이비 스와 들러 제품 기저귀 먼지 ? 너무 많 아요 . 기저귀 갈아줄 때 마다 아이 살 에 붙 은 기저귀 흔적 들 하얗 게 덕지덕지 . . 허벅지 사이 에 덕지덕지 아이 생식기 사이 에 도 붙 어 있 어요 . .. 그거 떼 어 내 느라 힘드 네요 . .. 그래서 지난 구매 끝 으로 팸 퍼스 구입 끝 할 렵니다 . 신중 구매 하 실 길 바래요 . 발진 없 다는 거 외 엔 좋 은 점 은 없 는 기저귀 네요 .',
#  'negative\t-- 15 g 주문 한 것 같 은 데 10 g 이 왔 네요 음 맛 은 그대로 옛날 맛 이랑 별반 없 지만 포장 색 이 선명 하 지 않 아 조금 그러 네요',
#  'negative\t--;; 가로 150 세 로 140 을 시켰 는데 가로 140 세 로 150 을 주 셨 어요 -_-;; 나머진 다 ? I 찮은 데 . ..',
#  'negative\t-.-',
#  'negative\t- 0 - 물건 을 만들 어서 보내 시 는 건가요 ? 티슈 두 개 보내 는 데 2 주 나 걸리 다니 ! ! 추천 안함 추천 안함 추천 안함 추천 안함 추천 안함 추천 안함 추천 안함 추천 안함 추천 안함 추천 안함',
#  "negative\t- 08 - 21 ) 현재 작성 가능 한 상품 리뷰 가 1 건 더 있 습니다 . 상품 리뷰 이벤트 진행 시 리뷰 를 작성 해 주 시 면 , 마일리지 적립 혜택 뿐 만 아니 라 현금 처럼 사용 가능 한 포인트 혜택 을 추가 로 드립니다 . 상품 리뷰 이벤트 자세히 보 기 구매 후기 / 상품 리뷰 는 ' 나 의 사이트 > 구매 후기 / 상품 리뷰 ' 에서 확인 / 수정 가능 합니다 . 확인 / 수정 바로 가 기 시각 장애 로 인해 밝 은 세상 을 볼 수 없 는 우리 아이 들 에게 여러분 의 따뜻 한 댓글 과 소중 한 기부 로 응원 해 주 세요 . ' 나눔 문화 의 새로운 시작 ' 사이트 가 희망 쇼핑 을 시작 합니다 . 희망 쇼핑 바로 가 기",
#  'negative\t-_- 바지 생각 보다 기 네요',
#  'negative\t-_-;; 한 번 쓰 고 너무 뻗 뻗 해져서 버렸 어요 3 만 원 짜리 다시 구매 해서 씁니다 싼 거 는 이유 가 있 네요',
#  'negative\t-_- 어 이상실',
#  'negative\t- ㅁ - 많 은 양 에 놀랐 지만 , 역시 질 은 많 ~~ 이 떨어지 네요 ㅠㅠ 어쩜 그리 솜 이 날리 는지 ㅠ 얼굴 에 도 솜 이 뭍 어 나 고 , 역시 가격 만큼 만 하 는 것 같 습니다 ㅠ 다음 에 는 좀 가격 이 있 더라도 , 솜 이 촘촘 하 고 안 날리 는 걸로 구매 해야 할 듯 ;',
#  'negative\t- 리뷰 수정 합니다 - 숀리 바이크 사 려고 벼르 고 있 었 는데 마침 세일 이 라 구매 했 습니다 . 조립도 괜찮 았 고 , 기존 쓰 던 싸이클 보다 무게 도 가볍 고 크 기 도 작 아서 공간 을 많이 차지 하 지 않 아요 . 옮기 기 도 쉽 습니다 . 화이트 라서 깔끔 하 고 예뻐요 . 소음 도 윙윙 휠 돌리 는 소리 정도 라서 괜찮 아요 . 매트 도 사이즈 딱 맞 으니 너무 좋 아요 : ) 추천 합니다 ! - 매트 는 별도 로 나중 에 배송 되 서 사진 에 는 매트 가 없 습니다 -- 리뷰 수정 - 2 월 초 에 구입 해서 현재 6 개월 사용 중 인데 벌써 아주 고장 이 나 버렸 습니다 . .? 점점 소음 이 발생 하 더니 아예 페달 이 헛 돕니다 . a / s 신청 해야 하 는데 , a / s 는 과연 잘 처리 해 주 실지 . . 수리 잘 되 면 다시 후기 수정 하 겠 습니다 .',
#  'negative\t- 수정 --// 한 달 도 안 되 어서 금가 버렸 습니다 떨어트리 지 도 않 았 는데 어디 에 살짝 부딪친 거 같 은데 금가 버리 네요 가루 도 있 는 거 같 고 영상 과 같 은 그런 효과 는 없 나 봅니다 다이소 5000 원 짜리 보다 더 빨리 깨지 는 거 같 네요 다시 는 비싸 게 주 고 사 지 않 을 것 같 아요 싼 거 여러 개 가 나 을 꺼 같 네요 --// s 9 인데요 가격 이 나가 서 혹시 잘못 붙 힐 까 걱정 했 는데 잘 붙 어 지 고 터치 는 한 번 씩 안 먹힐 때 도 있 는데 스크롤 이 정말 부드럽 게 잘 되 네요 일반 강화 유리 보다 강해 보여요 오래 잘 썼 으면 좋 겠 네요 ^^',
#  'negative\t- 좋 은 점 - 배송 전 미리 연락 을 주 는 시스템 이 라 수령 일 을 예상 할 수 있 었 고 배송 도 빠른 편 임 . - 아쉬운 점 - 조립 은 쉬 운편 이나 랙 연결 부위 가 끝 까지 물리 지 않 아 잘 빠짐 . 세로 1800 짜리 랙 이 휘어진 상태 로 배송 되 어 교환 이 귀찮 아 팬 치 로 힘들 게 펴 서 그냥 조립 함 . 상하 단 플라스틱 마감 이 헐 거 움 .',
#  'negative\t- 후면 카메라 보호 필름 - 2 개 구성 품 이 었 는데 왜 그런지 알 겠 는 . . ㅡㅡ 1 개 먼저 떼 어 붙여 보 니 접착성 이 없이 금방 떨어졌 음 . 그래서 설명서 를 보 니 보호 필름 을 떼 라 했 음 . 자세히 보 니 유리 위 에 필름 이 부착 되 어 잇 었 는데 손톱 으로 뗄 수 있 게 약간 나와 있 었 음 . 그걸 떼 니 유리 만 남 아 있 었 음 . 곧장 유리 가 부숴 짐 . 끝 두 번 째 꺼 떼 서 붙이 니 잘 붙 음 . 기포 는 있 지만 낼 까지 기다려 볼 예정 .',
#  'negative\t.',
#  'negative\t. 상품 가지 고 장난 하 지 마세요 . 뭐 하 시 는 겁니까 . . 액정 2 / 3 크기 강화 유리 라니요 . . G 950 이 라고 쓰인 커버 가 S 8 용 이 맞 는 건가요 ?',
#  'negative\t. . .',
#  'negative\t. . . , ㅇ왜이리딱딱한지ㅠㅠ그어지지가않고 눈 이 아파요 ㅠㅠ',
#  'negative\t. . . .',
#  'negative\t. . . . .',
#  'negative\t. . . . . . .',
#  'negative\t. . 제 가 생각 한 게 안 예요 . 힘 도 없 고 ㅜㅜ',
#  'negative\t. 왜 사이즈 가 안 맞 죠 ? 분명 줄자 로 재 서 구매 한 건데 트라이앵글 형 이 라 그런 건지 . . 그림틀 도 안 맞 고 너무 남 아요 . 생각 했 던 것 과 너무 다른 거 같 아요 . 반품 귀찮 아 사용 은 할게요 .',
#  'negative\t. 배송 은 괜찮 은데 . .. 제품 은 그냥 그럭저럭 이 네요 . 그냥 싼 맛 에 사용 합니다 . ... 크 게 기대 는 하 지 마시 길 . ..',
#  'negative\t. 택배 를 받 아 봤 는데 실망 스러웠 네요 . 치약 박스 는 없 거나 , 다 분리 가 돼서 왔 네요 . 포장 상태 가 아쉽 네요 .',
#  'negative\t. 생각 보다 별루 네요',
#  'negative\t. 부실 해요 .',
#  'negative\t.,.,.',
#  'negative\t.,..,',
#  'negative\t. .',
#  'negative\t.. . . . . . . . .',
#  'negative\t.. 면 ? 이 일어났 어요 . . 하루 입 었 더니 . . 나머지 두 가지 는 . . 어찌 될진 모르 는데 . . 이것 만 재질 이 다르 던데 . . 불량 이 아니 라 . . 옷 자체 가 이렇게 나온 듯 . . ㅠㅠ내던 만 원',
#  'negative\t.. 워낙 흰 계열 이 라 걱정 이 되 긴 했 는데 빨 고 나 면 괜찮 아 지 겠 지 싶 은 생각 에 구매 했 지만 빨 고 나 니 색도 빠지 고 쭈글쭈글 해져서 더 못 쓰 고 버려야 될 것 같 아요',
#  'negative\t.. 무슨 상자 에 원래 상자 곽 포장 도 없이 치약 들 만 달랑 왔 네요 좀 웃기 고 어이없 고 . . 정리 하 기 도 굉장히 ㅈ ㄹ 맞 네요 상자 곽 벗기 고 치약 만 넣 어서 보낸 건지 뭔지 진짜 . . 왜 이렇게 보내 나요 ? 진짜 너무 어 이 가 없 네요',
#  'negative\t.. 진짜 어지간 한 필름 다 혼자 서 붙여 왔 고 전문가 라고 할 만큼 동종 업계 종사자 라 괜찮 을 거 라 생각 하 고 샀 는데 제품 이 불량 인지 내손 이 꽝 손 인지 진짜 너무 안 붙 어서 붙이 다 붙이 다 결국 깨졌 습니다 , 지금 그냥 다 이 서 2000 원 짜리 필름 사 서 붙였 는데 그게 속편 하 네요 화면 도 깔끔 하 고',
#  'negative\t.. 처음 받 았 을 때 유리 밑 에 부분 에 아이폰 x 윗부분 모양 으로 이상 하 게 자국 이 남 아 있 다고 해 여 하나 ? 아무튼 유리 모양 이 달랐 어요 그랬 는데 . . 귀찮 아서 교환 요청 안 하 고 계속 썼 습니다 . 삼 일 째 되 는 날 쯤 부터 모서리 부분 들 이 여기 저기 자잘 하 게 깨지 더니 지금 은 만신창 이 네요 ㅋㅋㅋ ㅋㅋㅋ ㅋㅋ 강화 유 린데 . 정말 쉽 게 깨지 는 거 같 아요 . .. ㅠㅠ 일부러 돈 더 주 고 얇 고 비싼 거 샀 는데 . . 크 게 핸드폰 떨어트린 적 도 없 구요 . . 그냥 작 은 가방 에 넣 어 놓 는 게 다 였 습니다 ㅠㅠ 저 는 다 신 구매 안 할 거 같 아요 ㅠㅠ',
#  'negative\t.. 얼굴 에 바르 면 밀려서 몇 번 더 발라 봐야 겟 지만 . ..',
#  'negative\t.. 다른 건 멀쩡 한데 이건 . . ㅜ 딱히 제품 이상 은 있 는 거 아니 지만 괜히 그러 네요 다음 엔 배송 에 더 신경 써 주 세요 ~',
#  'negative\t.. 메모리 는 무슨 . . 그냥 얇 은 스폰지 . 그리고 도면 대로 짤랐 다간 낭패 그냥 자기 발 , 신발 깔창 크기 맞춰서 잘라야 함',
#  'negative\t.. 쓰 고 나 면 웬만 한 비누 보다 더 몸 이 뻑뻑 해요 빨래 비누 도 아니 고 . . 요즘 나오 는 비누 도 이렇 진 않 을 듯 . .',
#  'negative\t.. 생각 보다 별루 네요',
#  'negative\t.. 생각 보다 별루 네요 .',
#  'negative\t.. 생각 보다 별루 네요 ㅠ',
#  'negative\t...',
#  'negative\t... 세탁 시 물 빠짐 이 심해요 . 두 번 빨 았 는데 검은색 물 이 . .. 피부 가 걱정 이 됩니다',
#  'negative\t... 7 세트 중 4 개 가 불량 이 네요 . .',
#  'negative\t... 쭉 우레탄 필름 쓰 다가 고릴라 글라스 라 해서 써 봤 는데 처음 것 은 보이 지 는 않 는데 일부분 이 터치 가 잘 안 되 서 이것 으로 두 번 째 구입 하 게 되 었 습니다 . 온갖 노력 끝 에 간신히 깔끔 하 게 붙였 습니다 . 터치 도 이상 없 고 선명 하 고 마음 에 들 었 는데 5 일 째 되 는 오늘 박살났 습니다 . 약 1 m 높이 에서 떨어졌 는데 강화 유리 가 박살난 채 로 떨어져 핸드폰 에서 떨어지 더군요 . ..... 필름 값 이 한 장 에 사만 사 천 원 짜리 로 지금 까지 사 본 것 중 최고가 인데 . .. 선명도 하나 빼 고 는 기존 에 쓰 던 만원 짜리 필름 보다 떨어지 는 성능 에 경악 을 금치 못하 네요 . 요즘 나오 는 만 원대 필름 도 선명 하 기 도 하 고 성능 이 좋 아서 이전 핸드폰 의 경우 수없이 떨어졌 는데 도 표면 에 약간 의 흠집 만 자리 하 고 있 을 뿐 입니다 . 아 . . 금요일 밤 인데 물건 주문 하 면 빨라야 화요일 이 니 . ... 진짜 운 빨 안 좋 은 것 같 습니다 .',
#  'negative\t... 일단 배송 시간 은 나쁘 지 않 네요 주문 하 고 이틀 만 에 왔 습니다 그렇지만 그 뿐 이 에요 . 품질 은 일단 양 사이드 곡면 부분 이 떠서 손 으로 누르 면 꾹 눌리 는 게 느껴질 정도 구요 강화 유리 아래쪽 으로 화면 이 보여요 . 안쪽 에 , 그러니깐 액정 과 강화 유리면 사이 에 기름 번진 얼룩 같 은 게 없 어 지 지 않 네요',
#  "negative\t... 기대 했 던 것 보다 폭 이 너무 좁 아서 많이 수납 할 수 가 없 네요 . 가로 는 좁 지만 세로 는 조금 길 어요 , 일반 적 인 서랍장 의 경우 와 ' 가로 × 세로 ' 가 바뀌 었 다고 생각 하 시 면 됩니다 . 틈새 수납장 의 용도 로 는 나쁘 지 않 겠 으나 , 가격 에 비해서 그다지 좋 은 것 같 지 가 않 네요 . 요즘 서랍장 2 만 원 정도 로 도 크 게 잘 나오 던데 , 저 는 조금 후회 스럽 네요 . 참 , 서랍장 을 뒤집 어 보 면 ~ 서랍장 끼우 는 흰색 부분 이 , 아래 사진 에서 처럼 매 칸 마다 검정 색 으로 오염 되 어 있 었 어요 ! 물티슈 이용 해서 빡빡 지워 봤 지만 깔끔 하 게 지워 지 지 않 아요 . 무슨 화학 물질 인지 알 수 가 없 어서 다소 마음 이 무겁 네요 . 다행히 , 요청 대로 스티로폼 대 어 주 셔서 ~ 깨지 거나 부서진 부분 은 없이 잘 왔 기 에 , 그냥 씁니다 . 이 부분 은 감사 드립니다 . 참 , 서랍장 을 여닫 아 보 니까 , 쉽 게 빠지 지 않 도록 뭔가 지지 해 주 고 있 는 거 같 았 어요 . 배송 은 6 월 20 일 주문 해서 22 일 에 받 았 으니까 3 일 걸렸 어요 .",
#  'negative\t... 생각 보다 별루 네요',
#  'negative\t... 생각 보다 별루 네요 케이스 색상 이 화면 과 다름',
#  'negative\t... 그냥 그래요 ㅌㅊㄹㅇ ㅠㅅㅎ굣ㄱ ㅠ ㅛㅗㅅ구ㅕㅗㅛ셔ㅓㅛ 수 ㅗㅛ수ㅛㅗ수ㅕ 7 ㅛ , ㅔㅐ [ ㅔ ㅏㅓㅣ',
#  'negative\t... 유아 용 인지 . ..?',
#  'negative\t... 사진 이랑 다르 게 정말 . .. 싸구려 티 가 팍팍 선물 주 기 도 뭐 하 네요 끈 통 만 쓸 만 하 네요',
#  'negative\t... 변기 가 왔 어요 ㅡㅡ 샤워 텐트 시켰 는데 변기 가 왠 말 이 죠 . ....',
#  'negative\t..., 신 자마자 찍 은 사진 입니다 황당 쓰 .',
#  'negative\t....',
#  'negative\t.... 오늘 써 봤 는데 본드 에서 송진 냄새 에 미끌미끌 유리 자체 는 튼튼 하 다고 는 하나 우선 그 붙이 는 과정 이 까다롭 고 딱 처음 놓 는 그 순간 한 번 뿐 인 거 같 음 잡 고 기포 제거 할라 해도 틀어지 고 한 쪽 을 올리 면 반대쪽 송진 기름 같 은 게 미 는 쪽 으로 쏠리 고 하 진짜 . . 이건 뭐 하 자는 건지 말 자는 건지 좀 시간 이 지나 니 둔해 지 는 듯 한 느낌 도 있 고 ? 굳 는다는 거 겠 죠 ? 결국 처음 에 한 게 카메라 쪽 은 양호 두께 도 적절 하 게 되 고 밑 에 지문 쪽 은 두껍 게 발라 져서 기껏 눌 럿는데도 지문 인식 도 안 대 고 . . 하튼 뜯 어서 다시 하 기 로 결정 약통 도 한 개 더 있 구 하닌 까 바로 시도 닦 고 알콜 에 테이프 에 온갖 도구 를 이용 해서 필름 원상 복구 시켜 놈 이번 엔 약 을 조금 만 ~ 넣 고 하 는데 결과 는 아주 개차반 한 통 을 다 넣 으면 흘러넘치 고 조금 만 넣 으면 부족 하 고 띠 엇다 약 넣 었 다 하 다 . . 화 를 주체 못 해 뿌셔 버렸 습니다 와우 ~ 유연 해서 16 도 까지 구부리 닌 까 뽀 개지 더군요 그것 만 인정 많이 파 세요 전 불사조 쓰 겠 습니다',
#  'negative\t.... 실리콘 손잡이 를 추가 주문 했 는데 안 오 네요 . 까먹 고 안 주 신 건가요 ? 분명 제 주문 정보 에 는 정확 하 게 적혀 있 는데 실제로 는 받 지 를 못 했 네요 . 바쁘 신 건 아 는 데 까먹 고 안 챙겨 주 신 건 좀 그렇 네요 ㅜㅜ',
#  'negative\t.... 막 뜯 어 져 있 고 . .',
#  'negative\t.....',
#  'negative\t..... 260 주문 했 는데 박스 는 260 신발 은 270 전화 로 직접 교환 신청 했 는데 일 주일 이 넘 게 감감 무소식 . 글 남기 니 사이트 로 직접 문의 하 라고 하 고 . 면접 때문 에 한 번 신 어서 어쩔 수 없이 교환 포기 심지어 신 어 보 니 양발 사이즈 도 짝짝 이 . . 하 . .',
#  'negative\t..... yjnuyhmiku , lkj ㅣ ㅐ [ ㅕㅡㅏㅓㅗ , ㅏㅓ . ㅣ ㅏㅓ . / ㅔㅐㅑㅔㅐㅑㅔㅓㅏㅐㅑㅕ . ㅐㅑㅕㅗ',
#  'negative\t..... 왜 하나 는 비닐 이 벗겨져서 온 건지',
#  'negative\t......',
#  'negative\t.......',
#  'negative\t........',
#  'negative\t....... 리뷰 보고 구매 했 는데 터치 엄청 강하 게 눌러야 먹히 네요 . .... 지금 이 리뷰 작성 하 는 것 도 힘듭니다 돈 아깝 네요',
#  'negative\t......?',
#  'negative\t...... ㅎ',
#  'negative\t..... 왜 설치 법 은 따로 안 넣 어 보내 주 시 나 . ... 싶 네요',
#  'negative\t..... 단추 부분 금장 이 . . 너무 싼 티 난다 는 . .. ㅠ 그래도 싸 니까 . . 싼 게 비지떡 이 죠 . .',
#  'negative\t..... 외관상 가죽 은 괜찮 음 . .. 그렇게 싼 티 는 안 남 . .. 근데 뚜껑 여 는 순간 싼 티 폭 팔 어디 가 서 뚜껑 못 열 겠 음 그리고 따로 수납공간 도 없이 그냥 텅텅 그리고 가죽 안쪽 은 뭐 라 해야 하 지 살짝 기모 ? 같 은 부들부들 뻑뻑 까실까실 정도 . .?... 음 내 생각 엔 그냥 그 가격 . .. 하 는 것 같 음 . .',
#  'negative\t.... 맛 이 너무 없 어서 먹 다가 버 렷 어요 제 입맛 에 는 안 맞 는 듯 그냥 닭 가슴살 구워 먹 는 게 ㅜ나은것같아요',
#  'negative\t.... 기스 엄청 날 거 같 은 재질 에 배송 은 3 일 이 나 걸리 네요 . . 좀 불만족 스럽 네요',
#  'negative\t.... 전혀 다름 . .. 주황빛 1 도 없 음 . . ㄷ ㄷ 짜증 남',
#  'negative\t.... 박스 터져 와서 불안 했 는데 내용물 캔 은 멀쩡 한데 사은품 박살 . .. 하 . ..',
#  'negative\t.... 봉 이랑 커튼 을 같이 샀 는데 배송 이 따로따로 ㅋㅋㅋ 커텐 만 받 고 봉은 일 주일 후 에 받 았 는데 봉 끝 에 장식 이 깨져 와서 다시 받 았 어요',
#  'negative\t.... 상태 가 왜 이러 죠 교환 되 나요',
#  'negative\t.... 당연히 쓸 거 라 생각 하 고 구매 확정 눌렀 습니다 새 수건 이 라 세탁기 에 돌려쓰 려구 함께 산 새 옷 들 과 함께 헹굼 코스 로 돌렸 어요 . .. 세탁 이 끝난 후 한 번 털 어 널려 는 순간 눈 을 의심 했 어요 보풀 같 은 먼지 가 우수수 떨어져서 보 니깐 마치 부직포 가 물 에 녹 은 듯 한 먼지 들 이 자욱 하 더군요 ㅠㅠ 새로 산 옷 들 에 도 전부 요 . .. 그래서 저희 집 세탁기 가 먼지 가 많 아서 그런가 하 고 세탁 망보 니깐 먼지 가 3 분 의 1 정도 차 있 길래 그냥 새 세탁 망 으로 교체 하 고 수건 을 말린 후 ( 자연 건조 ) 다시 세탁 했 습니다 이번 엔 당연히 먼지 가 다 제거 되 겠 지 하 고 겨울 옷 정리 하 다 나온 검은색 타이즈 와 함께 세탁 했 습니다 근데 . .... 세탁 망 에 먼지 가 또 3 분 의 1 정도 차 있 고 멀쩡 했 던 타이즈 엔 온 데 다 먼지 같 은 보풀 이 . .. 다다다다 붙 어 있 고 그래도 세탁기 안 에 혹시 먼지 가 붙 어 있 나 싶 어서 물티슈 로 세탁기 몸 을 닦 아 주 고 싹 다 청소 를 한 뒤 이번 엔 세탁 망 볼 까지 넣 고 다시 돌렸 습니다 . . 돌리 고 난 후 먼지 가 또 차 있 고 세탁 볼 안 에 도 먼지 가 한웅 큼 나오 더라구요 . .. 혹시 설마 하 면서 수건 을 꼬집 듯 잡 고 살살 당겨 봤 더니 . .. 섬유 가 털갈이 하 는 강아지 털 마냥 수 수숙 뽑히 네요 . .... 먼지 가 왜 계속 나왔 는지 이해 가 가 더라구요 . ...... 판매 자분 이 리뷰 보 실지 모르 겠 지만 양심껏 판매 좀 해 주 세요 수건 덕분 에 새 옷 , 겨울 타이 즈 다 버렸 습니다 . .. 돈 은 돈 대로 쓰 고 물 의 물대 로 아깝 게 세탁기 3 번 돌리 고 . . 의도 치 않 게 자원 낭비 했 네요 . .. 앞 으로 는 인터넷 으로 수건 은 못 살 거 같 아요 ㅋ',
#  'negative\t.... 맛없 어 . ... 요 제 입 맛 에 는 최악',
#  'negative\t.... 이상 했 음 =_=',
#  'negative\t.... 기다리 고 기다려도 물건 이 안 와서 전화 했 더니 배송 실수 . ... 결국 일 주일 만 에 도착 . .. 전화 안 했 음 어쩔 뻔 ;;;;',
#  'negative\t.... 환 풍구 에 설치 했 는데 정차 할 때 환 풍구 가 부러졌 어요 ㅠㅠㅜ . ..',
#  'negative\t.... 안 번진다는 후기 보고 삿 는데 . .. 제눈에 는 아니 네요 . .. ㅠㅠㅠㅠㅠㅠ 한 시간 도 안 되 서 번지 기 시작 하 네요 . 그나마 갈색 이 라 다행 이 지 검은색 이 엇 으면 생각 만 해도 아찔 하 네요 ㅠ 심이 가늘 어 금방 부러지 는 게 단점 이 지만 섬세 한 꼬리 그리 기 랑 점막 채울 때 에 는 편해요 .',
#  'negative\t.... 처음 사용 할 때 읽 고 쓸 때 버벅 거려서 용량 큰 거 라 그런가 했 는데 사용 1 달 안 되 어서 뻑나 고 중요 데이터 날라갔 네요 삼성 복구 안 되 고 사설 복구 30 달 라는데 . .... 그 정도 중요 한 데이터 는 아닌지라 그냥 다시 만들 었 습니다 .',
#  'negative\t.... ㅠㅠ몸무게가 재 는 위치 에 따라 계속 바 껴요 . ..',
#  'negative\t.... 진짜 배송 늦 은 거 아님 . .. 괜찮 은데 . ... 배송 너무 늦 음 . .. 아 진짜 넘 한다 . ...',
#  'negative\t.... 여자 혼자 개뿔 입니다 앵 간 한 망치질 로 안 들어가 구요 온데 철제 다 쓰러져서 장판 헬 ? 楹 六 ? 수평 조절 할 수 없 다는 점 너무 힘들 다는 점 배송 느리 구요 앵글 하나 조 립 안 되 서 철 후벼 파서 꼽 았 네요 돈 을 이만큼 주 고 개 노가다 했 음',
#  'negative\t... 000',
#  'negative\t... 뭐 신발 산지 한 달 도 안 되 서 신발 옆 라인 터졌 네요 . 출퇴근 용 으로 만 ? 사용 하 는데 . 허 . 뭔 내구 성 이 이런지 . 275 사이즈 에서 270 사이즈 사면 맞 더라구요 . ..',
#  'negative\t... ㅡㅡ',
#  'negative\t... 뉴스',
#  'negative\t... 삐 아 아 라 섀도 6 년 동안 믿 고 ? ㎟ 粹 タ ? 이것 도 좋 겠 지 하 고 사 봤 는데 립 제품 은 좀 아니 었 나 봐요 틴트 에서 약 냄새 나 요 입술 살짝 핥 아 졌 는데 매우 썼 어요 이런 건 처음 이 라 계속 써야 되 나 망설여 지 네요 . ... 발색 은 그냥 그래요',
#  'negative\t... 삐 아 아 라 섀도 6 년 동안 믿 고 ? ㎟ 粹 タ ? 이것 도 좋 겠 지 하 고 사 봤 는데 립 제품 은 좀 아니 었 나 봐요 틴트 에서 약 냄새 나 요입 술 살짝 핥 아 졌 는데 매우 썼 어요 이런 건 처음 이 라 계속 써야 되 나 망설여 지 네요 . ... 발색 은 그냥 그래요',
#  'negative\t... 처음 신 을 때 는 좋 아요 . 한 번 빨 고 나 니 이게 나 를 신 은 건지 내 가 이걸 신 은 건지 모를 상태 가 됩니다 . 그냥 발 에 걸치 고 다니 는 꼴 이 되 어서 일회용 이 되 었 다는 ㅎㅎ',
#  'negative\t... 상품 상태 가 터지 고 영 아니 에요 . 사슴벌레 도 영 먹 지 를 않 네요 .',
#  'negative\t... 너무 얇 은 느낌 ?',
#  'negative\t... 사이즈 완전 작 아요 원래 235 신어 서 240 했 는데 좀 끼 어요 . 245 는 또 넘 클라나 . . 잘 몰 겠 어요 걍 좀 끼 게 신 을 라고요',
#  'negative\t... 마스크 가위 로 그냥 자른 듯 한 . . 왠만 해선 댓글 안다는 데 너무 하 시 네요 . .. 일단 급 해서 쓰 긴 하 는데 이런 시국 이 아님 절대 구매 안 했 을 거 예요 ㅡㅡ',
#  'negative\t... 아무리 저렴 해도 그렇 지 방울 이 손대 면 톡 떨어져서 손수 바느질 로 꿰맴 . 그리고 끈 으로 아무리 묶 어도 줄 줄 흘러 내림 그냥 모자 쓰 세여 다 들',
#  'negative\t... 제품 은 괜찮 은데 배송 때문 에 너무 스트레스 를 받 았 네요',
#  'negative\t... 제품 은 잘 받 았 습니다 . .. 근데 유통 기한 이 좀 그러 네요 . .. 아쉽 습니다 . ..',
#  'negative\t... 아이스 팩 다 녹 아서 왓 어요 ㅡㅡ',
#  'negative\t... 생각 보다 별로',
#  'negative\t... 어제 사고 오늘 아침 에 물건 넣 고 닫 았 는데 지퍼 고장났 어요 . .',
#  'negative\t... 디자인 도 괜찮 고 가격 도 저렴 해 구입 했 지만 과연 가격 만큼 의 금 함량 이 들어갔 는지 의문 이 들 정도 로 얇 은 줄 , 심지어 귀찌 마저 고무 귀찌 네요 ; 뭔가 돈 주 고 귀걸이 에 달린 큐빅 산 느낌 ? 이 정도 얇 기에 금귀 찌도 아닌데 왜 이 가격 에 받 는지 의문 이 네요',
#  'negative\t... 알레르 망 이불 쓰 는데 그냥 쓰 던 거 쓸 껄 몇 푼 아끼 려다 피부과 가 야 되게 생겼 네요 도착 하 자마자 빨 아서 사용 했 는데 남편 등 엄청 심한 아토피 인데 피부 에 안 맞 는지 밤새 피나 게 긁 어서 속상해요 . .....',
#  'negative\t... 너무 길 고 . . 너무 얇 고 . .. 돈 이 아깝 다 . .... 진심',
#  'negative\t... 너무 싼 티나',
#  'negative\t... 마니파 세요',
#  'negative\t... 펌프 부분 깨 ? 봅 楮 ? 뽁뽁 이 라도 감싸 야지 ㅡㅡ성의없네',
#  'negative\t... 돈 있 으면 좀 비싼 걸 살 껄 . ..',
#  'negative\t... 가격 이 싸 서 좋 은데 앞 지퍼 가운데 지퍼 다 불량 이 네요 불량품 을 보내 주 셨 네요 . .',
#  'negative\t.. 헐 한 번 신 었 는데 구멍 ㅠㅠㅡㅡ',
#  'negative\t.. ㅡㅡ',
#  'negative\t.. 이건 좀 별로 입니다 한번 입 고 빨 았 더니 . . 너덜너덜 . .-_- 완전 비추',
#  'negative\t.. 몇 일 신지 도 않 았 는데 실밥 이 뜯 어 지 는 건 무슨 상황 인가요 ? 그냥 교환 도 귀찮 고 몇 만 원 불우 이웃 도운 셈 칩니다 좀 상태 확인 하 고 배송 하 시 길 비추',
#  'negative\t.. 결 이 ㅅ ㄷ 완전 ㅡㅡ',
#  'negative\t.. 어렵 다',
#  'negative\t.. 색상 이 너무 달라요 ;;; 인디 핑크 인데 핑크 가 아니 고 . . 베이 지 . . 같 은',
#  'negative\t.. 뿌리 는 순간 에 만 잠시 향 이 퍼지 고 30 여분 뒤 손목 에 코 를 대 고 킁킁 거려 도 아무 냄 시 가 나 질 않 습니다 퍼퓸 이 라면서요 ? 어떻게 된 겁니까 판매자 님 ? ㅠㅠ',
#  'negative\t.. 본체 를 기본 옵션 에 넣 어 두 셔야 지 두 번 주문 하 게 만드 네요 ;',
#  'negative\t.. 구매 후기 여러 개 쓸 라니 쓸 말 도 없 음 .',
#  'negative\t.. 뽁뽁 이 가 하나 도 안 되 어서 그런지 새 서 왔 어요 다른 분 들 도 새 서 왔 다고 하 시 던데 다음 사람 들 에겐 뽁뽁 이 로 제대로 포장 해서 보내 주 시 면 더 나 을 듯 해요 배송 은 빠르 네요',
#  'negative\t.. 팬티 인지 밴드 인지 확실히 표시 좀 . . 팬티 인지 밴드 인지 확실히 표시 좀',
#  'negative\t.. 사용 한 지 한 달 만 에 샤 원기 입구 에서 구멍 이 하나 둘 새 어 지 기 시작 하 더니 두 달 만 에 호스 와 연결 하 는 틈 에서 물 이 새 기 시작 합니다 . ..... 사용 한 후 라 반품 도 못하 고 다시 사야 하 는데 , .. ㅠㅠ',
#  'negative\t.. 신발 에서 노란색 이 뭍 어 나 고 , 냄새 도 심하 고 . . 실망 이 커요 ! ㅜㅜ괜히산듯 . .. 하 아',
#  'negative\t.. 제 가 구입 한 아디 다스 바지 찐 이 아닌 거 같 습니다 아디 다스 로 고위 에 R 자 도 없 고 로고 도 너무 큰 거 같 고 정품 아닌 거 같 은데요 ㅋㅋㅋ 뭐 죠 ; ㅋㅋ 어 이 가 없 네요 바지 환불 해 주 시 면 좋 겠 는데요 ?',
#  'negative\t. 3 개 는 무사히 왔 는데 하나 가 완전 깨져서 도착 했 네요 . 세발 화분 대',
#  'negative\t. 5 ( 화 ) 하루 만 이 가격 클라이드 n 여름 필수 아이템 3 ea 반팔 티셔츠 및 인기 반팔 티셔츠 6 종 택 1 6500 원 스타일 / 색상 / 사이즈 : [ 008 ] A ( CCFTS 101 U ) 3',
#  'negative\t. 제발 합동 택배 좀 사용 하 지 말 아 주 셨 으면 좋 겠 습니다 . 저희 동네 에 는 할아버지 가 택배 를 운송 하 는데 , 다 세대 주택 2 층 이 라서 엘레 베 이터 가 없 습니다 . 무거운 짐 은 대문 까지 만 배달 해 주 고 , 가 는 경우 도 많 아요 . 포장 하나 는 제 가 옮기 고 , 매트리스 는 같이 옮겼 는데 , 이미 박스 를 엄청 굴려서 오 셨 더라구요 . 사진 에서 보 시 다시피 제품 이 밖 으로 튀어나와 있 습니다 . 반품 하 긴 뭐 해서 그냥 쓰 기 로 했 습니다 만 , 제발 , 노인 분 들 에게 무거운 짐 주 지 마시 구요 . 옮겨 주 지 도 않 을 거 라면 , 일 도 시키 지 말 았 으면 합니다 ~ 참고 로 젊 은 택배 기사 님 들 은 2 층 까지 와서 문 앞 에 두 고 , 사진 찍 어서 전송 해 주 시 고 가 십니다 . 제품 도 좋 고 배송 도 빨랐 지만 , 택배 기사 님 문제 로 점수 를 낮 게 드려서 죄송 합니다 . 큰 돈 드 는 거 아니 라면 , 제발 젊 은 분 들 많 은 택배 사 로 바꿔 주 세요 ~ 너무 어르신 한테 면전 에다 대 고 " 2 층 까지 들 고 오 세요 " 라고 말 도 못하 는 성격 이 라서요 . ㅜㅜ .',
#  'negative\t.·.·.·.·.·.·',
#  'negative\t. 싼 거 라고 했 는데 도 새 신 이 라 좋 은가 봐요 . 측면 밑창 과 갑피 연결 부분 만 어느 정도 견뎌 준다면 괜찮 을 거 같 아요 . 겉 으로 보 고 끈 을 묶 으며 신 어 봤 는데 가볍 게 걷 기 에 는 이상 없 네요 . 그래도 토우 캡 부분 이 약해 보여요 . 제품 에 문제 있 으면 리뷰 수정 할게요 . * * 사진 과 같이 검 은 바닥 창 이 보 기 와 달리 많이 물러 금방 닳 고 말 겠 어요 . ..',
#  'negative\t. 삼각 받침대 주문 는데 . . 삼각 뜰채 를 배송 했 네요 ㅜ . 반품 하 려 전화 했 더니 월요일 정신 없 으 션 지 . . 아예 안 받 고 . . . 출조 일정 땜시 인근 매장 가 서 다시 급 구매 ㅜ . . 덤벙 한 일 처리 로 시간 . 돈 버림',
#  'negative\t. 기존 에 있 는 것 보다 덜 두꺼운 듯',
#  'negative\t. 그럭저럭',
#  'negative\t. 저 렴 이 가 있 어 구매 했 는데 . .. 역쉬 . .. 보풀 심하 게 생기 구 . 밑 이 그리 길 지 않 아 벗겨지 네요 ~~',
#  'negative\t. 생각 보다 별루 네요',
#  'negative\t. 생각 보다 별로 네요 .',
#  'negative\t. 간략 하 게 정리 할게요 . . 상품 은 버렸 습니다 . . 음악 파일 , 재생 순서 , 한곡 재생 , 파일 선택 등 작동 시스템 이 엉터리 네요 . . 저렴 한 중국 산 상품 그 자체 입니다 . . 아까운 3 만 원 만 날렸 네요 .',
#  'negative\t. ㅗ아요하 . ㅣ 맛 어떤 ㄷ . ㅣ 몰',
#  'negative\t. 다른 기저귀 쓰 다가 발진 이 심해서 페넬로페 미라클 셔링 으로 시켰 는데 박스 여 는 순간 고무 냄새 ? 엄청 심해요 기저귀 팩 냄새 인 거 같 아요 . 기저귀 에 도 냄새 다 나 구요 . 후기 보 니 그런 글 은 없 네요 왜 제 껀 만 그런지 . .. 기저귀 팩 냄새 가 너무 심해요 이걸로 쭉 쓰려 했 는데 냄새 때문 에 시키 기 도 겁나 요 . 꼭 좀 조취 좀 취해 주 세요 . 팩 너무 싸 구려 쓰 시 는 거 아닌가요 아님 프린팅 을 잘못 하 셨 던가 ; 기저귀 에 도 냄새 가 배 니까 답 이 없 네요 이미 급 해서 쓰 신 했 는데 베란다 에 냄새 빼 고 있 어요 . 조취 좀 요 . ..',
#  "negative\t/ , l ; kkokll ;,; l , ; l , , ';, okpokpokk 0 k - 0 k - k [ ;,;', , ., llklklklk ; lk ; lk",
#  'negative\t/ 4 ㅣ ㅏㅂㅁ',
#  'negative\t0',
#  'negative\t0 0 0 0 0 0',
#  'negative\t0 0 0 0 0 0 0 0 ×',
#  'negative\t0 케이블 연결 했 다 뺐 는데 바로 고장나 네요 . .. 후면 카메라 쪽 은 잘 붙 는 듯 하 는데 전면 풀 커버 는 끝 모서리 쪽 은 계속 에어 가 들어간 듯 보이 고 제 가 잘못 붙인 것 일 수 도 있 지만 접착력 도 약해서 바로 바로 떨어지 네요 잘못 구매 한 듯 해요',
#  "negative\t0 - 5 점 접착력 5 점 : 살짝 올려 놨는데 도 빠르 게 잘 붙 음 기포 도 없이 한방 에 붙 음 . 터치 감 3 점 가장 얇 은 두께 로 구매 했 는데 좀 심하 게 터치 가 안 먹힘 속 이 빈 유리 를 누르 는 느낌 . 투과율 2 점 ' 빛 투과 율 이 높 다 ' 라고 하 시 던데 그것 과 다소 차이 가 있 는 사항 인지 는 모르 지만 , 붙이 자마자 유리 필름 에 비치 는 빛 반사 가 어마어마 하 게 심해져서 밝기 를 올리 지 않 고 는 화면 이 잘 안 보이 는 지경 임 코팅 4 점 손 에 땀 이 많 아 지문 이 잘 보이 는 편 임 쌩 화면 에서 는 거의 안 보이 던 지문 이 진하 게 남 는 모습 을 볼 수 있 지만 앞서 말 한 대로 땀 이 많 아서 그런지라 일반 적 인 사용 환경 에서 는 매우 괜찮 은 수준 이 라고 생각 함 마감 1 점 꽤 고가 의 제품 인데 도 불구 하 고 테두리 검은색 부분 으로 칠해져 있 는 부분 이 고르 지 못하 고 삐죽삐죽 튀어나와 있 음 신경 쓰 지 않 아도 보일 정도 . 저 가 형 제품 에서 볼 수 있 는 마감 처리 . ( 첨부 사진 윗 쪽 부분 마감 불량 ) 총평 : 접착력 과 코팅 이외 에 는 모두 불 만족 입니다 . 다시 는 구매 하 지 않 을 예정 입니다 . 많 은 제조사 들 이 차용 한 고릴라 글라스 이 긴 하 지만 , 제품 마감 의 부실 함 과 애플 워치 필름 을 샀 는데 도 관련 성 이 적 은 일반 핸드폰 필름 붙이 는 방법 이 적혀진 설명서 가 들 어 있 는 등 ( QR 로 들어가 야지 확인 가능 한 종이 가 ' 따로 ' 있 었 음 ) 업무 체계 가 부실 하 다는 것 이 잘 느껴졌 습니다 . 많 은 제조사 필름 을 붙여 봤 지만 가격 대비 이렇게 불 만족 인 제품 은 처음 입니다 . .. ps . 앞선 평가 와 는 별개 로 고릴라 글라스 4 를 채용 했 습니다 . 이 는 S 7 A 7 등 이전 모델 차 용 제품 입니다 구매 에 참 고 바랍니다 .",
#  'negative\t0 . 1 인데 생각 보다 두꺼운 느낌 이 고 , 홈 버튼 하 고 수화 부분 이 정확히 일치 가 안 되 고 살짝 오 차 가 나 네요 .',
#  'negative\t0 . 15 mm 사 서 부착 하 다가 삑 사리 . . 대충 부착 해서 쓸까 했 는데 두꺼운 거 같 아서 출장 가 기 전 에 0 . 1 mm 로 다시 주문 했 는데 먼지 가 2 개 껴 있 어서 재 부착 시도 했 지만 실패 . 짜증 나 서 버려 버린 비운 의 강화 유리 ㅡㅡㅋ',
#  'negative\t0 . 15 mm 구매 했 는데 핸 폰 에 붙일려 고 필름 에서 떼 다가 윗부분 이 깨져 버렸 네요 . 내 구성 이 너무 약한 거 아닌가요 ? ?',
#  'negative\t0 . 15 시 켯는데 0 . 25 보내 주 시 고 1 + 1 인줄 알 고 시켰 는데 메신저 광고 해야 하 고 암튼 확인 안 한 내 잘못 이 니',
#  'negative\t0 . 1 mm 구매자 입니다 일단 터치 감 이 좋 아 만족 을 하 고 싼 가격 이 아니 기 때문 에 오래 오래 쓰 자는 생각 을 가지 고 만족 중 이 었 습니다 하지만 이거 강도 가 너무 . . 떨어트리 지 도 않 았 는데 참 . .. 그냥 핸드폰 을 자동차 포켓 에 놔두 고 운전 을 하 고 내려서 ? f 더니 그냥 깨져 있 더군요 . .. 무지무지 약합니다 . . 사 실려면 0 . 1 mm 비추 합니다 사 자마자 대 실망 . .',
#  'negative\t0 . 1 mm 보호 필름 이 쉽 게 금 이 가 서 0 . 15 mm 로 구매 했 는데 폰 사이즈 보다 너무 작 게 나왔 습니다 . 그리고 이전 에 비해서 기포 도 많이 발생 되 고 제거 가 어려워 요 .',
#  'negative\t0 . 1 미리 주문 했 는데 0 . 21 미리 가 도착 하 여 전화 했 는데 . .. 안 받 아 그냥 부착 사이즈 에 딱 맞음 but 범퍼 케이스 에 넣 으니 들뜸 현상 . 어떻게 사용 하 나 . .. 고민 중',
#  'negative\t0 . 21 시 켰 는데 0 . 1 이 왔 더라구요 근데 급 해서 그냥 썼 는데 하루 이틀 만 에 깨져서 금 이 가 있 네요 . . 제 가 핸드폰 을 함부로 다루 지 는 않 는데 휴 . .',
#  'negative\t0 . 21 mm 너무 약합니다 . 두께 는 ? 고 좋 은데 부착 한지 하루 만 에 쌀 짝 찍힘 에 금 이 생겼 네요 . 더 두꺼운 걸 살 껄 후회 하 네요 . 표시 9 h 강도 이상 이 라 해서 구입 한 건데 생각 보다 너무 실망 입니다 .',
#  'negative\t0 . 21 mm 가 아주 조금 두꺼운 정도 입니다 .',
#  'negative\t0 . 21 인데 두껍 네요 그리고 액정 내부 도 부착 이 잘 안 되 고',
#  'negative\t0 . 29 mm 로 주문 했 는데 . 0 . 21 mm 로 왔 구요 . 네 고 제품 벌써 여섯 번 째 구매 예요 . 손 에 닿 는 이물감 이 없 어서 계속 구입 하 긴 했 는데 , 오른쪽 사진 처럼 훅 하 면 금가 고 깨져서 이젠 다른 데 로 바꿔야 겠 어요 . 액정 유리 보호 한다고 버린 돈 이 얼만 건지 . 만 원 안 되 는 저 가 형 으로 쓸 때 도 폰 쓰 는 동안 글 래스 커버 바꿀 일 이 별로 없 는데 . 네 고 제품 은 눌러서 안 깨 짐 뭐 하 나요 . 작 은 충격 에 도 금 이 쩍쩍 가 는데 . 소비자 들 파손 문의 에 상품 은 좋 은데 , 사용 자 문제 라는 답변 들 보 니 이건 진짜 아니 다 싶 네요 . 계속 29 , 000 원 짜리 구입 하 다 ( 이젠 정말 돈 아까워서 ) 처음 으로 만 오 천 원 대 주문 했 는데 , 오 배송 되 니 . 많이 파 시 고 번창 하 세요 . 제품 만드 는 본사 에선 개발 에 돈 좀 쓰 시 구요 .',
#  'negative\t0 . 29 mm 주문 했 는데 붙이 고 보 니 0 . 21 mm 제품 임 . 좌우 폭 이 실제 화면 크기 에 너무 꼭 맞 아 부착 어려움 . curved edge 가 다른 제품 ( 유사 가격대 ) 에 비해 매끈 하 지 않 음 .',
#  'negative\t0 . 29 를 선택 입금 했 는데 0 . 21 로 오 고 . .. 배송 느리 고 . .. 추천 하 지 않 습니다',
#  'negative\t0 . 29 를 신청 했 는데 0 . 21 이 왔 군요 . 이전 에 타사 0 . 3 제품 을 쓰 다가 깨졌 는데 . .. 우연히 1 + 1 행사 여서 좋 은 기회 로 구입 하 였 고 , + 1 을 위하 여 양식 에 맞추 니 왔으나 구매자 들 에게 는 좋 은 소식 이 지만 구매 시 잘못 배송 된 것 은 급해서 그냥 사용 하 는데 + 1 을 위한 조건 에 맞춰 블로그 올리 고 리뷰 올리 고 구매 후기 던가 올렸 는데 , 받 은 제품 은 일반 상기 에 첨부 된 사진 과 같이 또 잘못 배송 되 는 군요 . 두 번 다 잘못 배송 되 서 사고 기분 은 별로 입니다 . 실제 적 으로 1 + 1 개념 을 잘못 알 고 있 는 네 고 코리아 같 습니다 . 배송 은 택배 업체 에서 하 는 것 이 니 빠릅니다 만 제품 의 퀄리티 는 어떤지 사용 후 에 후기 올리 겠 습니다 .',
#  'negative\t0 . 29 하나 0 . 21 하나 해서 두 개 주문 했 는데 0 . 21 로 두 개 왔 어요 . .',
#  'negative\t0 . 29 미리 두 장 을 아이폰 6 플러스 와 G 4 용 두장 구매 ? E 는 데 0 . 21 미리 로 오 더니 상품 리뷰 를 왜 이렇게 보내 느 나 기분 나쁘 단 식 으로 후기 쓰 고 구매 확정 한 거 다시 보내 준다고 그러 며 후기 쓴 거 지우 겠 다더니 후기 지운 후 로 입 싹 닫 네요 1 주일 째 깜깜 무소식 입니다',
#  'negative\t0 . 4 mm 는 너무 뚜껍 고 타이트 한 케이스 를 끼우 면 필름 이 들뜨 네요 돈 버리 지 말 고 신중히 선택 하 시 길 바랍니다 .',
#  'negative\t0 . 5 차 이 라 스판 을 믿 엇 고 조금 작 은 사이즈 가 이쁘 다고 해서 구매 햇 더니 스판 끼 도 별로 없 고 이상 해요 ;;; 교환 하 기 도 애매 하 고 그래서 그냥 쓸 렵니다 ;;',
#  'negative\t0 . 5 cm 깔창 맞 는가요 그냥 깔창 같 은데요 ㅡㅡ 운동 화 에 있 는 깔창 하 고 비교 해봐도 차이 없 는데 . .',
#  'negative\t003 m 을 주문 햇 는대 002 L 로 보내 주 는 경우 는 뭐 에 요 ?',
#  'negative\t005 s 업 글 한 거 사 서 설치 비 5 만 주 고 했 는대 상하 좌우 반전 켁 . .. 이거 뭐 욕 박 에 안 나오 네 . ..',
#  'negative\t007 번 을 주문 하 였으나 008 번 이 왔 습니다 . 귀찮 아 그냥 씁니다 .',
#  'negative\t009 번 화질 이 생각 보다 별로 입니다 . ..',
#  'negative\t010 - 3149 - 0337 연락 주세요 20 번 도 안 오 고 10 종 에 9 종만 도착 햇 네요 어떻게 하 실 겁니까 답장 도 없 으시 고 참',
#  'negative\t02 번 폴라 티셔츠 가 03 번 지퍼 로 왔 네여 . .. 02 번 품절 이 라 지퍼 로 보냈 나 봐 여 . .. 전화 라도 주 고 확인 했어야 되 는 거 아닌가 . ..',
#  'negative\t04 . 상품 시켰 는데요 입 는 오버 나이트 4 px 3 개 라고 쓰여 있 는데 상품 이 2 개 밖에 안 왔 어요 잘못 기재 된 건가요 ? 확인 바랍니다',
#  'negative\t04 / 06 10 시 12 분 결재 함 04 / 07 19 시 41 분 교환 요청 ( 사이트 문 의 답변 ) 1 . 바퀴 를 결합 하 니 락 이 안 걸려 바퀴 가 빠집니다 . ( 하나 키우 면 다른 하나 가 빠집니다 . ) 2 . 유선 형 뚜껑 3 개 중 1 개 ( 연두색 ) 가 다른 뚜껑 에 비해 이격 이 큽니다 . 3 . 하 단 흰색 받침 도 뚜껑 처럼 락 이 걸려 고정 이 되 어야 하 지만 락 걸리 는 부분 이 없 어 쉽 게 빠집니다 . 위 와 같 은 문제 발생 그리고 ABS 라 그런지 보 ( 쉽 게 말 해 플라스틱 이물질 비슷 함 ) 가 많 은 편 이 고 뚜껑 에 수축 ( 쉽 게 말 해 플라스틱 에 굴곡 ) 도 있 음 아마도 사출 할 때 압력 조절 을 못 했 거나 이 형제 를 과다 사용 했 을 거 라 생각 됨 . 04 / 11 답변 이 없 어 재 문 의 요청 함 04 / 11 16 시 30 분 경 전화 옴 . 업체 에서 불량 여부 다시 확인 요청 함 . 04 / 12 불량 인 부분 동영상 과 사진 카톡 으로 보냄 04 / 14 업체 에서 카톡 으로 연락 옴 . 불량 이 맞 고 다시 배송 하 겠 다고 함 . 업체 에 철저 한 검수 요청 함 . 04 / 15 제품 배송 옴 . 조립 할려고 보 니 뚜껑 2 개 파손 그리고 뚜껑 도 이격 이 큼 . 파손 내용 사진 을 찍 어 카톡 으로 업체 에 보냄 . 바로 확인 만 함 . ( 하지만 금요일 저녁 이 라 답변 은 없 음 . ) 사이트 문 의 답변 에 글 올림 . 04 / 18 업체 에서 연락 이 없 어 직접 연락 함 . 이번 엔 파손 된 뚜껑 2 개 만 배송 하 겠 다고 함 . 포장 에 신경 써 달 라고 요청 함 . 04 / 18 불량 뚜껑 포장 하 던 중 고리 3 개 중 1 개 가 깨 짐 . 고리 가 스텐 이나 스틸 인 줄 알 았 는데 플라스틱 에 크롬 도색 으로 되 어 있 어 쉽 게 깨 짐 . 판매자 배송 비 가 부담 될 거 같 아 그냥 깨진 상태 로 쓰 기 로 결정 . 04 / 19 뚜껑 2 개 배송 옴 . 체결 해 보 니 맨 처음 받 을 때 와 같이 뚜껑 이격 이 큼 . ( 판매자 는 신경 도 안 쓰 는 듯 ) 판매자 와 언쟁 하 기 싫 어 그냥 열풍기 로 녹여서 이격 을 최소 화 시켜 사용 함 . ■ 결론 04 월 06 일 결재 해 04 월 19 일 ( 13 일 ) 온전 한 상품 배송 받 음 . 조치 가 너무 느림 . 누구 나 실수 나 불량 을 낼 수 있 지만 그 에 따른 조치 가 느리 다면 신뢰도 도 떨어지 고 이미지 도 떨어짐 . 차후 본 업체 와 거래 하 지 않 을 예정 임 . 업체 명 을 바꾸 고 상품 게시 한다면 아마도 모르 고 구매 하 겠 지만 ㅋㅋ ■ 장점 온전 한 제품 을 받 았 다면 활용 도 좋 은 괜찮 은 제품 하 지만 판매자 를 잘못 만남 . ■ 단점 배송 은 빠른 편 이 지만 판매자 를 잘못 만나 불량 조치 가 매우 느림 . 옵션 으로 구매 한 비닐 100 매 ( 8000 원 ) 는 비싼 편 . 다른 제품 검색 해 보 니 4 , 000 대 제품 임 ( 배송 비 별도 ) 하단 흰색 받침 도 뚜껑 처럼 락 이 걸려 고정 이 되 어야 하 지만 락 걸리 는 부분 이 없 어 쉽 게 빠집니다 . 케이블 타이 로 묶 어 사용 중 본 업체 는 질질 끌 다가 7 일 간 후 자동 구매 승인 으로 할 거 란 생각 이 듬 < URL >',
#  'negative\t04 / 26 일 에 구입 해서 배송 은 빠르 더군요 , .. 04 / 27 일 , 28 , 29 , 05 / 02 , 03 , 04 , 06 , 09 , 오늘 이 05 / 11 일 이렇게 . . 구두 신 은지 딱 9 일 댔 네요 . . 헌데 벌써 구두 뒷부분 굽 부분 이 바닥 과 떨어져서 틈 이 생겨서 언제 떨어질지 모르 겠 네요 . . 솔직히 싼 가격 이 라 대충 3 개월 정도 신 고 버리 고 다시 사 곤 했 지만 . . 약 9 일 정도 되 어서 떨어질 거 라곤 생 각지 도 못했 는데 . . 이따위 구두 를 파 는지 모르 겠 네요 . . 제 가 하 는 업무 가 험한 것 도 일반 사무직 인데 . . 대부분 을 앉 아서 지내 는데 . . 누가 보 면 완전 험하 게 다룬다고 하 겠 네요 . . 기왕 상품 파 시 는 거 좀 제대로 된 제품 으로 파셨 으면 하 네요 . .',
#  'negative\t046 옷 이 왜 이렇게 무거워 요 옷 전체 무게 가 장난아 님',
#  'negative\t04 T 가 맞 나 싶 을 정도 로 너무 흐 물 거림 . 퀄리티 떨어져서 쓰 기 싫 을 정도 .',
#  'negative\t05 ) mkk - 15 ss 4000 주문 은 36 인데 , 표기 38 사이즈 가 오 고 실측 은 36 도 38 도 아닌 이상 한 제품 . 더구나 가을 팬츠 라면서 얇 은 여름 용 . 심하 게 늦 는 발송 까지 . 왜 이런 판매 를 하 는지 .',
#  'negative\t05 . 엘 루이 쉴드 풀 커버 글라스 투명 1 + 1 이거 구매 했 는데 1 + 1 ? ? 이 라 함 이 하나 는 new , 하나 는 used 로 보내 는 건가 ? ? 하나 는 새 거 맞 는데 , 한 개 는 안쪽 접착 부분 보호 필름 도 떨어져 있 어서 이미 끈 적 이 부분 에 먼지 투 성 이 고 , 누구 손가락 인지 모르 겠 으나 , 지문 이 4 개 나 뭍 어 있 는데 , 이걸 쓰 라고 보낸 건지 ? 알 수 가 없 소 ? ? 판매자 는 누군가 반품 했 던 것 을 확인 ( ? ) 도 안 하 고 , 다시 구매 자 한테 발송 한 거 같 은데 used 로 판단 되 는 필름 은 더러워서 쓸 수 없 기 때문 에 내 가 분질러 버렸 네 장사 하 려면 제대로 확인 해서 팝시다 . 한 대 는 이미 붙여서 몇 천 원 때 매 교환 반품 이 귀찮 아 진행 은 안 하 는데 , 상당히 불쾌 하 구만 . ㅡㅡ 거 . ........',
#  'negative\t051 - 628 - 9553 여기 서 전화 받 는 여자 분 면봉 안 왓 다고 전화 햇 더니 한숨 팍팍 쉬 면서 싸가지 없 게 대꾸 하 고 완전 도로 가져가 라고 하 려다 미친 엑스 똥 밟 은 셈 치고 다신 여기 서 안 산다',
#  'negative\t051 - 628 - 9553 여기 서 전화 받 는 여자 분 이 래서 소비자 가 잘 도 사 겟 다 너 때메 다신 여기 서 안 산다',
#  'negative\t07 년 식 뉴 오피러스 입니다 . 집 에 차 그 랜 져 TG 는 싸이 즈 딱 좋 고 실수 없이 왔 는데 07 년 식 뉴 오피러스 는 뒷좌석 고정 핀 없 는 타입 인데 고정 핀 이 있 는 게 왔 네요 뉴 오피 이후 프리미엄 부터 뒷좌석 고정 핀 이 있 는데 잘못 만들 었 네요 운전석 쪽 은 악셀 앞쪽 담배 1 각정 도 크기 로 짤라 져 있 네요 . ..',
#  'negative\t09 년 도 8 월 11 일 껄 보내 시 면 어떡 합니까 ? .. 비닐 두 벗겨지 구 . . 누가 쓰 다만 거 같 은 . 장난 하 나요 ? . 이런 제고 제품 판매 하 면 안 되 는 거 아닌가요 ? 쫌 기분 안 좋 네요 . .',
#  'negative\t09 선택 했 는데 10 보내 주 는 센스 ! ! 귀찮 아서 교환 신청 안 합니다 ㅎ',
#  'negative\t0 ~ 3 세 아이 가 쓰 기 엔 모 가 미 세모 인데 도 자극 적 이 에요 돈 버렸 어요 ㅠ좋은거사서쓰세요',
#  'negative\t0 점 이 없 네요 ;; 실버 주문 했 는데 골드 가 왔 어요 환불 하 는 절차 가 너무 복잡 하 길래 그냥 쓰 고 있 는데 제대로 확인 하 고 안 보내 주 셔서 좀 그렇 네요 ;;',
#  'negative\t1',
#  'negative\t1 + 1 이 라고 해서 산 건데 . .. 전화 통화 도 안 돼 고 . .. 이메일 로 보내 준 안내대 로 사이트 에서 신청 하 는 것 도 안 돼 고 . .. 빠른 확답 부탁 합니다',
#  'negative\t1 + 1 으로 구매 했 는데 하나 는 제품 이 정상 적 인데 하나 는 두 번 뿌렸 는데 빈 통 이 되 어 있 네요 . . 증발 할 수 가 있 나요 ? 도대체 이해 가 안 되 네요 . 하나 가격 을 이 금액 에 산 거 면 완전 비싸 게 산 거 잖 아요 ~ 하나 교환 해 주 세요 . !',
#  'negative\t1 + 1 이 라 구입 한 건데 하나 만 왔 어요 어떡 해 된 건가요 갤럭시 노트 8 입니다',
#  'negative\t1 + 1 이 라더니 구성 품 2 장 이 라 되 있 어서 합 이 4 장 오 는 줄 알 았 는데 1 장 에 1 장 더란 말 이 네요 ㅠ 그럼 절 때 저렴 한 거 아닌 거 같 아요 ㅠ기분나빠요',
#  'negative\t1 + 1 인줄 알 았 는데 그게 아니 네요 ! 넘 비싸 게 사 서 매우 배 아픔',
#  'negative\t1 + 1 행사 라고 해서 샀 더니 딸랑 한 개 만 왔 어요 . 고객 센터 에 전화 하 니 블랙 만 1 + 1 이 고 . 다른 건 다 1 개 가격 이 라고 . . 참 . .. 웃기 게 장사 하 네요 . . 분명히 어제 1 + 1 으로 봤 는데 . . 오늘 다시 들어가 니 페이지 가 다 바뀌 었 네요 . .. 딜 떠서 구매 한 건데 . . 원래 파 는 가격 이랑 같 다니 . . 참 웃기 게 장사 하 시 네요 . . 암튼 . . 블랙리스트 에 올려요 . . 그렇게 장사 하 지 마세요 . . 장사 똑바로 하 세요 ! !!!!!',
#  'negative\t1 주일 은 괘 안 음 . . 그 이후 는 영 별로 1 주일 은 괘 안 음 . . 그 이후 는 영 별로 1 주일 은 괘 안 음 . . 그 이후 는 영 별로',
#  'negative\t1 구두 에 스 크러치 나 있 음 2 구두 끈 묶 는 첫 번 째 바로 밑부분 에 본드 작 욱 남 있 음 . 불 만족 합니다 . 3 키 높이 신발이 여서인지 무슨 여성 들 하이힐 신 은 정도 임 완전 공중부양 임 . 비추 합니다 .',
#  'negative\t1 ) 뒤 변속기 고정 용 볼트 와 너트 가 반대쪽 에 도 제공 되 지 않 아서 뒤 바퀴 의 회전 시 균형 이 맞 지 않 습니다 , 높이 를 맞추 는 볼트 및 너트 를 보내 주 시 기 바랍니다 . 2 ) 또한 차체 의 뒤 바퀴 고정 부분 이 휘 어 있 어서 기어 의 최 고단 으로 변속 이 불가 합니다 .',
#  'negative\t1 * 1 3 D 쉴드 강화 유리 2 개 총 4 개 구매 했 는데 터치 감 거 지 같 고 4 장 하루 만 에 다 떨어지 고 그냥 대리점 필름 이 더 좋 은 듯 하 네요 돈 만 날린 듯 ㅜㅜ',
#  'negative\t1 + 1 이 라 하 더니 하나 는 완전 뒤틀린 걸 보냈 네요 반품 하 기 도 그렇 고 하나 삿 다 하 고 쓰 려구요',
#  'negative\t1 + 1 29900 원 시켰 는대 하나 만 왔 어요 . . 확인 바랍니다 . 빠른 배송 넘 좋 고 품질 도 좋 아서 두 번 째 시키 는 건대 . ㅜ ㅜ연락 좀 주 세요 . .',
#  'negative\t1 + 1 ( 150 + 150 마리 ) 이 라 해서 300 마리 주문 햇 는데 세 어 보 니 얼추 200 마리 정도 밖 에 안 되 는 것 같 네요 ~ ㅜ . ㅜ',
#  'negative\t1 + 1 한 봉 더 준다고 해서 구매 했 더니 3 봉만 왔 네요 . 이건 뭔지 . ..',
#  'negative\t1 + 1 한 봉 더 준다고 해서 구매 했 는데 정작 3 봉만 왔 네요 . 이건 뭔지 . ..',
#  'negative\t1 + 1 한 봉 을 더 준다고 해서 구매 했 는데 정작 3 봉만 왔 네요 . 이게 뭔지 . ..',
#  'negative\t1 + 1 인 레깅스 + 심리 스 쇼 츠 를 함께 구입 했 어요 . 레깅스 는 가격 이 비싼 편 인데 그럭저럭 입 을 만 해요 . 심리 스 쇼 츠 는 입 을 게 못 되 요 ~ 유니 * 로 보다 얇 아서 쇼 츠 가 말리 네요 . 별로 에요 . 이 너 웨 어 상품 은 반품 이 안 된다고 했 지 함께 산 레깅스 는 부분 반품 은 안 된다는 말 은 없 던데 왜 안 해 주 는 거 죠 ? 귀찮 아서 쇼 츠 는 버리 고 레깅스 만 입 어요 .',
#  'negative\t1 + 1 에 쿠폰 까지 싸 게 는 산 거 같 은 데 사 고 나 니 아토 팜 안 좋 은 보도 났 던 거 뒤늦게야 알 아서 찜 찜 최근 제조 일자 니까 나쁜 성분 빼 고 리뉴 얼 되 었 으려나 . . 안토 엔 오 투 도 좋 다고 들 하고',
#  'negative\t1 + 1 꼭 상 품평 해야 되 요 ? 진짜 귀찮 네 제품 은 그냥 보통',
#  'negative\t1 + 1 이 , 그냥 주 는 + 1 이 아니 라 제품 본사 홈페이지 방문 하 여 리뷰 를 별도 로 작성 하 고 , 추가 적 인 배송 비 를 착불 로 줘야 함 으로 번거롭 고 추가 요금 이 들 어 갑니다 . 그냥 1 개 가격 으로 는 보호 필름 이 너무 비싼 듯 합니다 .',
#  'negative\t1 + 1 인데 병 과 돌 이 한 개 씩 만 왔 어요 ㅜ',
#  'negative\t1 + 1 으로 3 개 구입 했 는데 1 개 가 포장 이 없이 먼지 잔뜩 묻혀 배송 되 어 왔 네요 ! !!!',
#  'negative\t1 + 1 인줄 알 고 구매 했 는데 무슨 리뷰 를 적 어야 되 나 보 네요 ? 여 디 에 상 품평 이 아니 라 따로 적 는 곳 이 있 나요 ?',
#  'negative\t1 + 1 으로 와서 양 은 굉장히 많 아요 ~ 속눈썹 도 연장 한 거 같이 이쁘 구요 근데 잘 안 붙 어요 ~ 붙이 는 데 가 낚시 줄 로 얇 은 줄 이 라 붙여 도 잘 떨어지 네요 ~ 검정 색 으로 변하 는 풀 도 강력 하 지 않 아요 ~ 기존 화장품 가게 에서 팔 던 속눈썹 풀 을 썼 는데 그게 훨씬 강력 해요 . 속눈썹 은 진짜 자연 스럽 고 이쁜 데 붙이 는 라인 이 너무 얇 아서 잘 안 붙 는 게 많이 흠 이 라 별 3 개 네요 . 속눈썹 붙이 는 시간 이 20 분 걸려요 . 그만큼 잘 안 붙 네요 . 양쪽 붙이 는 데 5 분 안 에 끝나 는데 이건 진짜 안 붙 어요 ㅠ 다음 엔 이뻐 도 다시 사 고 싶 진 않 네요 . 앞 에 가 계속 들려서 열심히 붙이 고 나가 도 떼 어 내 버리 기 바빴 어요 ㅠ',
#  'negative\t1 + 1 으로 바지 삿 는데 사이즈 가 30 하 고 32 가 왓 어요 반품 하 기 귀찮 아서 걍 허리 맞 는 사람 아무 나 주 려구요 .',
#  'negative\t1 + 1 인거 보 고 산 건데 . . 왜 1 + 1 이 아닌 단 품 . .? 1 + 1 은 그냥 낚시 인 건가 . .? ㅡㅡ 왠지 속 은 느낌 이 . .',
#  'negative\t1 + 1 인줄 알 고 주문 했 는 눈 탱 이 맞음 투명 글라스 에 왜 페인팅 은 해 가지 고 고유 색상 을 가리 는지 ? 엣지 부분 까지 페인팅 되 서 화면 이 축소 됨 ! 거기 에다 엣지 부분 굴절 왜곡 으로 화면 이 더더욱 축소 됨 ! 터치 감 아주 떨어짐 특히 홈 버튼 양쪽 으로 터치 감 거의 없 음 이건 터치 가 아니 라 누름 버튼 이 되 어 버렸 네 ! 그냥 우레탄 필름 붙일 란다 4 만 원 버렸 네 . . 뭔 이벤트 에 사진 을 올리 래 ? 핸드폰 으로 핸드폰 을 찍 으라고 ? 자기 눈 으로 자기 눈 을 보 라는 건가 ?',
#  'negative\t1 + 1 인줄 알 고 주문 했 는데 하나 네요 살짝 부딪혀도 금방 깨 집니다 ㅠ 벌써 두 번 째 주문 이 였 는데 두 번 사고 두 개 째 해 먹 고 후기 씁니다',
#  'negative\t1 + 1 이 라 싼 맛 에 샀 는데 , 수압 상승 이 라 했 는데 수압 은 별로 . .. 열 어 보 니 아무것 도 없이 텅 비 어 있 는데 어떻게 수압 상승 하 는지 . 어째 튼 별로',
#  'negative\t1 + 1 더치 패브릭 c 타입 고속 충전 케이블 구매 하 였 습니다 . 제 폰 은 겔 럭 시 노트 FE 인데 C 타입 충전 짹 자체 가 맞 지 가 않 내요 . 어찌 이런 일 이 C 타입 은 다 동일 한 거 아닌지요 ?',
#  'negative\t1 + 1 이 라 가격 은 좋 네요 그런데 . . 2 구 스위치 에 불 이 안 들어와요 ㅜㅜ 이거 교환 해 주 셔야 되 는 거 아닐까 싶 어요 ㅠ',
# ...
#  'negative\t11 월 16 일 구매 하 여 20 일 배송 받 았 습니다 . 딱 10 일 정도 사용 하 니 바로 고장나 네요 AS 센터 는 연락 도 안 되 고 요 참고 하 셔서 구매 하 세요',
#  'negative\t11 월 29 일 구매 하 여 만족 하 게 사용 하 고 있 었 는데 오늘 폰 을 꺼내 보 니 상단 부위 에 금이 가 있 네요 . 싸구려 강화 유리 대신 비싼 가격 의 강화 유리 를 구매 한 건데 한 달 도 않 되 서 금 이 가 다니 어의 가 없 네요 .',
#  'negative\t11 월 29 일 에 배송 받 고 또 깨졌 네요 첫 번 째 는 지 마켓 에서 구매 ? E 고요 이번 에 는 사이트 에서 구 맨데 산지 일 주일 도 안 돼서 깨지 네요 ;; 지난번 에 도 같 은 제품 써 보 고 부착 도 편하 고 평점 도 좋 고 화면 도 선명 한 듯 해서 내 부주의 로 깨 졌나 보다 하 고 비싸 지만 조심 해서 오래 쓰 자고 생각 하 고 두 번 째 로 산 건데 일 주일 도 안 돼서 깨 지니 좀 그렇 네요 한두 푼 도 아니 고 광고 에서 는 강화 유리 고 내구력 좋 다고 홍보 돼 있 는데 저 랑 은 안 맞 는 건지 원래 후기 잘 안 올리 는데 글 올려 봅니다',
#  'negative\t11 월 2 일 주문 한 모래 가 아직 도 배송 이 안 되 었 네요 ! 이게 뭔가요 . .?! 배 송지연 보상 이런 거 안 되 나요 ?',
#  'negative\t11 일 2 세트 총 6 박스 구매 ㅡ 15 일 한 박스 만 도착 29 일 참다참다 문 의 글 남김 ㅡ 29 일 오후 배송 시작 30 일 5 박스 마저 도착 했 습니다 . 정말 . .. 배송 최악 입니다 . 한 박스 만 왔 을 때 19 일 부터 다시 배송 해 준다면서 그것 도 열흘 이나 걸렸 네요 .',
#  'negative\t11 일 2 세트 총 6 박스 구매 ㅡ 15 일 한 박스 만 도착 29 일 참다참다 문 의 글 남김 ㅡ 29 일 오후 배송 시작 30 일 5 박스 마저 도착 했 습니다 . 정말 . .. 배송 최악 입니다 . 한 박스 만 왔 을 때 19 일 부터 다시 배송 해 준다면서 그것 도 열흘 이나 걸렸 네요 .',
#  'negative\t11 월 3 일 ~ 11 월 7 일 수령 배송 이 빠른 가요 ? 그리고 이벤트 를 하 시 던데 . .. 먼저 산사람 은 X 신 만드 시 네요 순식간 에 취소 해 버리 고 다시 결제 하 려다가 그냥 넘어갑니다 . 그냥 억울 그 자체 지요 . 빨리 산 죄 . 사은품 은 나눠 드세요',
#  'negative\t11 월 3 일 에 주문 하 여 11 월 12 일 에 물건 을 받 아 봤 습니다 . 해외 배송 도 이렇 게 까지 오래 걸려 받 아 본 경험 이 없 습니다 . 중간 에 몇일 째 같 은 자리 에 머물러 있 는 점 이 이상 해 판매자 에게 배송 문제 문의 했 지만 형식 적 인 물량 증가 로 양해 바란다는 이야기 뿐 . 직접 적 인 대처 가 없 었 습니다 . 판매자 는 물건 을 출고 한 뒤 에 는 사후 문제 에 대해서 는 적극 적 인 처리 를 안 하 네요 . 오죽 하 면 제 가 직접 2 번 이나 한진 택배 에 고객 불만 을 접수 하 여 물건 을 찾 고 이렇게 오늘 배송 을 받 을 수 있 었 습니다 . 물건 이 오 는 도중 에 7 일 이상 지연 된다고 보 면 누구 나 문제 로 삼 지 않 겠 습니까 . 판매자 의 천편일률 적린 응대 및 답변 에 다시 는 이 업체 에서 물건 을 구매 하 지 않 아야 겠다는 생각 입니다 .',
#  'negative\t11 월 3 일 에 주문 해서 2 - 3 일 후 받 아 신 었 는데 11 월 17 일 어제 이렇게 됐 네요 조금 씩 떨어지 더니 한 번 에 확 ! !!!! 10 일 좀 더 신 었 는데 그것 도 삼실 에서 만 신 은 건데 이렇게 되 는 건 넘 심하 지 않 나요 ? 한 달 도 아니 구요 버리 긴 아깝 구 수선 집 에 맡겨야 하 는 상황 . ... 이 정도 면 새 걸루 바꿔 주 셔야 하 는 거 아닌가요 ?',
#  'negative\t11 월 5 일 주문 ( 201811054354671 ) 해서 11 월 9 일 부착 했 습니다 우리 집 애 들 이 보 다가 떨어뜨린 모양 인데 2 주 정도 지나 서 보 니 오른쪽 가장 자리 에 위 에서 밑 으로 3 / 4 정도 가 금 이 쭉 ~~ 간 네요 상품 이 좋 다고 해서 구입 했 는데 조금 실망 입니다',
#  'negative\t11 월 5 일 주문 한 제품 이 11 월 24 일 도착 했 네여 티스푼 갖 고 싶 어서 산 거 라서 좀 늦 어 진건 괜찮 은 듯 포장 은 잘 되 서 왔 구여 티스푼 도 여 쁘고 좋 내 여 요새 택배 아저씨 들 고생 하 시 는 듯 모두 힘 네 시 길',
#  'negative\t11 월 5 일 에 주문 했 는데 지금 은 23 일 이 네요 ㅡㅡ 배송 중 이 라고 뜨 기 만 하 고 조회 도 안 되 고 ~!!! 판매 자분 이 글 본다면 취소 처리 해 주 시 던가 아니면 빨리 배송 해 주 세요 진짜 너무 합니다 .',
#  'negative\t11 월 5 일 주문 11 월 12 일 도착 배송 엄청 빠르 네여 까먹 었었 는데 와서 이게 뭐 지 했 네여 고맙 습니다 ㅋㅋ',
#  'negative\t11 월 7 일 날 주문 하 고 가지 고 있 다 25 일 날 방화동 장 착점 에서 장착 해 봤 다 . 근데 운전석 조수석 의견 을 물 어 보 지 않 고 달 아 주 는 건지 . .. 헐 ~ 안 보인다 ! 그래도 개인 적 인 건 운전석 인데 . . 본인 은 최악 이 다 ! 룸 밀 러 재껴야 셋 팅 및 안전 운전 볼 수 있 다 ! 원래 올란도 차량 이 저 자리 라면 별 다섯 개 수정 이 다 ! 개인 적 으로 별 하나 도 아깝 다 !',
#  'negative\t11 월 7 일 신청 11 월 15 일 도착 리뷰 에 남겨진 것 처럼 포장 박스 다 찢어지 고 테이프 로 감싸 져 있 고 상품 몇 개 찌그러 짐 ㅡㅡ 다행 이 라 생각 해야 하나 다른 분 처럼 없 어 진건 없 어요 감사 합니다',
#  'negative\t11 월 8 일 날 주문 을 하 고 11 일 캠프 를 하 려고 했 는데 14 일 도착 을 했 네요',
#  'negative\t11 월 9 일 ) 사실 옵션 이 잘못 왔 지만 주말 동안 못 붙이 는 것 보다 는 그냥 쓰 려고 교환 신청 은 안 했 습니다 . 11 월 11 일 추가 ) 며칠 사용 해 보 니까 엣지 부분 은 확실히 붙 질 않 아서 터치 가 간헐 적 으로 씹 힙 니다 교환 신청 이 하 고 싶 습니다 . 11 월 12 일 추가 ) 터치 씹 힘 으로 문 의 넣 어서 살짝 떼 서 다시 붙여 보 라는 답변 을 받 았 는데 절차 대로 살짝 떼 는 순간 파괴 되 었 습니다 이 유리 가 충격 에 약한 것 이 믿기 질 않 네요 그래도 접착력 은 좋 은 것 같 네요',
#  'negative\t11 일 날 주문 한 기저귀 28 일 이 돼서 야 겨우 받 았 네요 도선료 추가 로 생겼으면 안내 를 해 주 던가 아무런 연락 도 없이 가만히 있 지 않 나 도선료 만 총 12 , 000 원 냈 는데 또 사은품 은 빼놓 고 왔 네요 사은품 은 3 팩 오 는 건데 박스 두 개 값 도선료 를 내 고 그냥 한 박스 에 들어가 는 양 일 텐데 어찌 보내 시 려고 그러 는 건지',
#  'negative\t11 일 주문 17 일 도착 너무 느려요',
#  'negative\t11 일 구매 17 일 오후 에 물건 받 았 습니다 상담원 형편없 고 택배 아이 고',
#  'negative\t11 일 저녁 주문 해서 13 일 에 받 았 어요 배송 빨라요 여기 푸 셔 는 괜찮 은 지 한 번 구입 해 봤 는데 저 는 별로 인 것 같 아요 집 에 있 는 것 보다 잘 안 되 네요 . . 젤 네 일 셀프 로 해 보 려고 여러 가지 여기 서 구입 했 는데 다른 건 괜찮 은 데 푸 셔 는 별로 임',
#  'negative\t11 일 새벽 1 시 경 주문 해서 12 일 오후 배송 받 았 어요 . 일단 펼쳤 을 때 말려 있 던 부분 에 선 ? 이 생겼으나 . . 시간 이 지나 면 풀리 겠 죠 ? 밟 을 때 소리 나 는 건 이불 이나 면종 류 아니 고서 야 소리 안 나 는 게 이상 한 거 같 고 . . 마트 에서 비슷 한 매트 두 개 샀었 는데 다 소리 는 났 어요 . ㅋ 10 일 날 구매 하 려고 담 아 뒀 는데 11 일 에 쿠폰 써서 싸 게 잘 샀어요 ^^ 필로티 층 이 라 두께 1 . 6 은 필요 없 을 거 같 아서 1 . 2 샀 는데 그리 얇 게 느껴 지 진 않 았 어요 ~ ㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡㅡ 2 개월 20 일 사용 후 수정 비닐 이 뜨 네요 ;; 이러 다 찢어져 버리 고 . . 2 . 3 . 4 번 째 사진 추가 올립니다 . . 하루하루 새로운 부분 이 떠요 . . 곧 버리 게 생 겻 네요 . ㅡㅡㅡㅡㅡㅡㅡㅡ 5 개월 ? ㎢ 쨉 ⅳ 빱 ? 사망 하 심 . . ㅋㅋㅋ',
#  'negative\t11 일 멤버 쉽 이용 하루 지나 자마자 쇼킹 딜 ㅡㆍㅡ 농간 당하 는 기분 자주 바꾸 려고 2 개 주문 했 더니 싼 것 두 아니 네 . ..',
#  'negative\t11 일 빼빼 로 데인 데 10 일 날 오후 에 오 는 건 뭐 ?',
#  'negative\t11 일 주문 한 상품 이 17 일 에 도착 했 어요 . . 발송 은 빨리 해 주 셨 는데 . . 배송 조회 하 니 . . 상품 이 돌고돌 았 더라구요 . . 글구 . . 250 ml 하나 덜 왔 어요 . . ㅠ . ㅜ',
#  'negative\t11 번 버킷 백 주문 했 는데 겉 은 괜찬은데 속 에서 잘못 봉재 되 서 물건 이 안 들어가 서 그냥 버렸 습니다 . 안감 문제 인 줄 알 고 안감 없이 라도 쓰 려고 뜯 었 더니 반품 안 된다고 하 네요 . 2 만 원 돈 날렸 네요 . 역시 싼 게 비지떡 이 네요 .',
#  'negative\t11 일 주문 해서 22 일 받 았 습니다 박스 재 활용 하 시 나 봅니다 다시 구매 하 고 싶 지 않 습니다 고객 센터 전화 받 지 도 않 는데 구색 맞춰 올렸 는지',
#  'negative\t11 월 초 중순 에 신청 해서 3 ~ 4 주 만 에 받 았 습니다 . 배송 기다리 는데 많이 화났 죠 . 늦 어 지 는 데 에 대한 이렇 다 저렇 다 설명 도 없이 운송장 번호 미리 등록 해 두 고 , 배송 추적 되 길 기다리 며 사흘 정도 기다려도 추적 이 안 돼서 택배 회사 에 확인 했 더니 보낸다는 등록 만 한 것 일 뿐 물건 을 넘겨 받 지 못한 상황 이 라고 설명 했 습니다 . 판매자 와 전화 통화 를 어렵 게 했 는데 미안 하 는 말 보다 본인 들 변명 대기 에 바쁘 더군요 . 사이트 말 고 도 여러 군데 에서 진행 되 기 때문 에 주문 이 많이 밀려 있 다고 - 배송 은 10 일 정도 라고 걸릴 거 라고 주장 하 는 것 과 는 반대 로 신뢰 를 깨트리 며 소화 도 못 할 주문 은 왜 계속 받 는 건지 . .. 다음 날 보내 고 연락 주 겠 다더니 , 연락 은 없 었 지만 물건 은 바로 택배 사 로 넘겼 더군요 . 역시 전화 를 해야 일 처리 가 바로 되 는 건가 싶 었 네요 . 상품 은 그럭저럭 그냥 편하 게 막 다루 기 에 괜찮 습니다 만 , 너무 오래 기다려서 반품 하 기 가 두렵 더군요 . 암튼 상품 이 너무 마음 에 들 었 어도 배송 때문 에 만족 스러운 평 은 힘들 었 을 것 같 네요 .',
#  'negative\t11 개 주문 했 는데 10 개 만 왔 습니다 . 업체 든 사이트 든 연락 바랍니다 . 사이트 에 는 9 월 2 일 에 전화 했 는데 , 토요일 이 라 상담원 이 없 다고 빠른 시간 내 에 전화 준다고 하 더니 벌써 1 주일 지났 습니다 . 완전 개판 입니다 . 이런 글 쓰 는 사람 만 뭐 랄 께 아니 라 제대로 좀 하 시 죠 . .!!',
#  'negative\t11 개 신청 했 는데 7 개 만 왔 습니다 . 확인 해 주 세요',
#  'negative\t11 개 신청 했 는데 7 개 만 도착 했 습니다 확인 해 주 세요',
#  'negative\t11 월 이벤트 라고 적혀 있 어서 아직 주 는 줄 알 고 5 만 원 이상 주문 했 는데 사은품 도 안 주 고 그럴 거 면 광고 를 내렸 어야죠 서운 하 네요',
#  'negative\t11 일 주문 한 상품 이 11 일 째 오 지 도 않 고 . .. 업체 는 전화 도 안 받 고 . .. 이거 완전 쓰레기 임 절대 절대 사지 마시 고 다른 업체 에서 구매 들 하 시 길 . ..',
#  'negative\t11 일 멤버십 까지 써서 샀 는데 공홈 이 더 싸 네요 ㅜ',
#  'negative\t11 일 그래 놀라 카카오 호두 510 g 짜리 2 개 를 주문 했 습니다 300 g 짜리 2 개 가 배송 되 어서 510 g 짜리 로 맞교환 받 았 는데 이번 엔 유통 기한 이 지난 것 이 배송 되 었 네요 또 맞교환 받 았 습니다 맞교환 덕분 에 일 주일 만 에 받 았 네요 배송 하 시 기 전 에 꼼꼼 한 확인 이 필요 할 것 같 습니다 한두 달 전 에 시킨 같 은 상품 의 유통 기한 은 내년 6 월 까지 던데 이건 올해 12 월 까지 네요 그 전 에 다 먹 긴 하 겠 지만 유통 기한 이 많이 남 지 않 았 다는 건 입 고 된지 시간 이 많이 지난 상품 일 꺼 란 생각 이 드 네요',
#  'negative\t11 일 구매 상 품미 도착 인데 판매 자문 의 시 택배 사 에 머물러 있 다고 하 는 등 어떻게 하 라는 건지 모르 겠 는 답변 을 줍니다 . 답변 은 사이트 에 만 주 는지 . . 전 한 번 도 제대로 된 답 못 받 았 어요 . 판매자 전화 연결 안 됩니다 . 답답 그 자체 네요 .',
#  'negative\t11 월 10 일 설치 하 였 습니다 . 11 월 11 일 서울 로 와서 휴대폰 으로 CCTV 재생 을 검색 하 다가 깜짝 놀랬 습니다 . 밤 에 세입자 가 출입 할 때 센서 등 이 껴 지 고 꺼질 때 깜빡 깝빡 하 는 증상 이 발생 되 곤 합니다 . 어떻게 해야 되 는지 알려 주 세요 . 포장 박스 도 버렸 느 데 ~~',
#  'negative\t11 월 11 일 주문 에 23 일 에 수령 했 습니다 너무 배송 이 늦 기에 문 의 글 남겼 더니 누락 되 었 다고 하 는데 문의 안 했 으면 언제 배송 될지 알 수 도 없 었 겠 네요 가격 은 저렴 하 고 제품 도 아주 마음 에 들 지만 배송 부분 신경 좀 썼 음 하 네요',
#  'negative\t11 년 12 월 12 일 제조 ! 재고 정린 가요 ? 사은품 주 질 말 던가 옆 이 뜯 어 진 물티슈 를 어떻게 쓰 나요 ! 5 월 제조 라더니 이런 . .',
#  'negative\t11 월 19 일 오전 에 주문 을 했 는데 아직 상품 이 도착 하 지 않 았 습니다 . 주문 , 배송 상태 는 배송 완료 라고 뜨 는데 이건 무슨 경우 인가요 ? 고객 센터 , 택배 사 연락 도 안 되 고 너무 하 네요 .',
#  'negative\t11 월 19 일 배송 완료 바로 붙이 고 사용 중 너무 막 ? ㎡? 벌써 크랙 남 3 번 째 구입 인 대 생각 보다 정말 쉽 게 크랙 나 는 듯 차라리 1 만 원 이하 제품 이 좋 을 듯 괜시리 비싼 건 괜찬것지 하 고 삿 는데 신중히 구입 들 하 세요',
#  'negative\t11 월 20 일 에 주문 하 여 15 일 만 에 받 았 습니다 . 사무실 에서 비치 하 고 먹 으려고 4 박스 나 주문 했 는데 배송 이 지연 된다는 어떤 멘 트 도 하나 없 고 배송 추적 도 안 되 고 직접 전화 해서 물어봐도 확인 후 연락 주 겠 다고 한 후 아무런 연락 도 없 고 사은품 으로 온 무드 등 은 건전지 를 넣 어도 작동 되 지 도 않 고 불량 이 고 정말 짜증 나 네요 . . ㅠㅠ',
#  'negative\t11 월 21 일 주문 하 여 12 월 7 일 받 음 . ... 택배 사 교체 해야 할 듯 . ..',
#  'negative\t11 월 25 일 에 받 아서 착용 하 고 있 는데 두 달 도 안 되 양쪽 밑창 이 다 갈라졌 네요 . 신발 여러 켤레 가지 고 신 고 잇 는데 한쪽 도 아니 고 양쪽 이 같이 이런 경우 는 첨 이 네요 . 가 성비 좋 은 것 같 아 구매 했 는데 . .. 환불 이나 교환 처리 해 주심 이 어떨 런지 요 .',
#  'negative\t11 월 28 일 주문 해서 12 월 11 일 받 았 습니다 . 배송 문의 로 게시판 에 글 쓴 건 올해 처음 인듯 . . 도저히 못 참 고 취소 요청 하 니 그날 오후 6 시 에 물건 도착 ; 근데 사이즈 까지 커 버림 . . 패드 없 어서 집 에 남 는 거 잘라 써야 겠 음 . .',
#  'negative\t11 월 28 일 구입 하 고 20 일 만 에 원인 모르 게 강화 유리 에 금 이 감 . 12 윌 28 일 재 구입 이번 에 는 10 만 에 강화 유리 에 금 이 감 . 제품 자체 에 신뢰 가 의심 되 기 시작 합니다 . 그리고 이 벤드 내용 대로 1 + 1 안 합니까 ? 조치 해 주 세요 . 2019 년 1 월 9 일 리뷰 수정 11 월 구입 하 고 잘 사용 하 고 있 다가 어디 서 부 딧쳐 금 이 쫙 가 서 불량 인가 하 다가 자세히 보 니 부 딧친 흔적 이 이 다 . 휴 ~~ 퓨어 코 릴라 강화 유리 아니 면 액정 이 나 가 새 휴대폰 사 야 할 뻔 , 그래도 또 다시 고릴라 강화 유리 를 또 재 구매 를 하 네요 지난번 에 는 이벤트 신청 도 안 했 는데 이번 에 는 혹시나 하 는 맘 에 이벤트 신청 을 해 봅니다 .',
#  'negative\t11 월 28 일 주문 해서 12 월 5 일 받 음 kgb 택배 진짜 배송 뭐 같 네 물건 주문 전 에 어느 택배 사 배송 인지 이제 알아보 고 주문 해야 겠 음 KGB 택배 가 배송 이 면 돈 좀 더 줘도 다른 판매자 한테 주문 하 리라 마음먹 음 최악 의 택배 사 KGB 택배',
#  'negative\t11 월 29 일 주문 해서 12 월 27 에 받 았 어요 거의 한 달 만 에 받 았 고 모자 에서 냄새 많이 납니다',
#  'negative\t11 월 2 일 주문 하 고서 야 11 월 6 일 수요일 이제야 받 았 네요 요즘 사이트 에서 주문 하 먼 도착 예정일 보다 훨 늦 게 도착 하 고 소비자 입장 에서 는 도착 예정일 을 보 고 주문 하 는 데 요즘 은 늦 어 지 는 게 당연 하 다는 느껴 지 는데 차라리 도착 예정일 고시 를 하 지 말 아야 할 것 아닙니까 ?',
#  'negative\t11 월 30 일 에 도착 했 는데요 냄새 가 너무 나 서 아직 도 사용 할 수 가 없 네요 작은방 방치 되 어 있 어요 언제 쯤 이 면 쓸 수 가 있 을까요 ㅠ . , ㅠ',
#  'negative\t11 월 3 일 주문 했 는데 상품 이 잘못 와서 교환 처리 . 11 월 9 일 교환 상품 받 아 봤 습니다 . 가격 , 포장 , 배송 , 교환 처리 , 서비스 다 별 롭 니다 .',
#  'negative\t11 월 4 일 주문 해서 하두 안 와서 딴 거 사 서 받 고 취소 하 려니 송장 번호 넣 어 놓 고 ~ 택배 추적 안 돼서 게시판 문의 했 더니 택배 사 쪽 전산 오류 라 해 놓 고 이틀 뒤 에 왔 네요 . 오래 걸리 고 거짓말 하 고 ~ 진짜 송장 번호 미리 넣 어 놓 는 거 뿌리 뽑혔으면 좋 겠 네요 . 제일 짜증 나 요 ~~',
#  'negative\t11 월 5 일 에 구매 했 는데 오늘 왔 네요 배송 이 정말 최악 이 예요 절대로 이곳 에서 구매 않 할 거 예요 계속 배송 중 이 라고 해서 취소 도 못하 고 최악 입니다',
#  'negative\t11 월 5 일 주문 / 11 월 17 일 도착 ~ 배송 이 이렇게 늦 었 도 누구 하나 빈말 이 라도 죄송 하 다는 한마디 가 없 네요',
#  'negative\t11 월 7 일 주문 했 는데 도착 은 15 일 에 하 고 3 단주 문 했 는데 2 단 이 왔 네요 전화 는 계속 통화 중 에 어쩌 라는 건지 답답 하 네요',
#  'negative\t11 월 8 일 날 구매 했 는데 와 벌써 아래 사진 처럼 다 뜯 어 졌 네요 엄하 게 사용 한 것 도 아닌데 모 죠 ? 첫 번 째 사진 은 하도 안 되 서 저렇게 테이프 로 붙 쳤 네요 두 번 째 사진 은 엊그제 붙 혔 고 요 아니 3 개월 도 안 되 었 는디 이건 넘 한 거 아닌가요 ? 한마디 로 겉 은 단단 하 고 속 은 개판 이 라는 ㅜㅜ',
#  'negative\t11 일 절 3 업체 에 실사 주문 했 고 여기 가 처음 으로 왔 어요 . 커버 랑 아래 봉 에 상당히 굵 은 기스 가 이어져 있 구요 . 이미지 가 사진 보다 흐리 게 나왔 구요 . 이미지 화질 떨어질 거 염려 되 서 단순 한 거 했 는데 올겨울 지나 고 바꿔야 겠어요 . 이미지 화소 가 낮 은 게 섞여 있 는지 모르 겠 으나 후기 보 니 호불호 가 좀 갈리 는 거 같 군요 . 여러분 롤리폴리 같 은 거 하 지 마세요 . 색감 처참 하 고 퀄 떨어져요 .',
#  'negative\t11 개월 9 키 로 아기 한테 커요 같 은 5 단계 라도 팬티 는 입히 겠 는데 밴드 형 은 허리 에 신축성 이 거의 없 어서 흘러 내리 내요 똥 다 새 겠 어요 첫째 때 밴드 형 사고 후회 했 던 걸 잊 고 있 었 네요',
#  'negative\t11 일 에 주문 ~ 14 일 저녁 에 ? 굶 勞 楮 ? 당일 배송 은 거짓말 이 었 니 봐요',
#  'negative\t11 개월 아가 범 보 한 쪽 다리 로 끌 고 다녀서 구매 했 는데 너무 만족 해요 ~~~',
#  'negative\t11 개월 잡 고 걷 는 남아 사용 . 크기 는 타 제품 과 비슷 하 고 써 본 제품 이 한정 적 이 라 정확 한 건 아니 지만 뭉침이 좀 많 은 편 입니다',
#  'negative\t11 일 이 되 니 머그 컵 증정 이 빠져 버렸 습니다 . 추가 할 인 때문 에 컵 을 빼 버렸 네요 !',
#  'negative\t11 일 에 주문 해서 17 일 날 받 았 네요 기저귀 이렇게 늦 게 보내 면 어떻게 하 란 건지',
#  'negative\t11 일 에 주문 하 고 18 일 에 받 음 ㅡㅡ 늦 는다는 문자 한 통 도 없 고 . . 하 아',
#  'negative\t11 일 에 주문 한 게 18 일 에 왔 습니다 . 늦 은 건 둘째치 고 머리띠 2 개 주문 하 면서 빗살 추가 했 는데 빗살 하나 도 안 왔 습니다 . 반품 하 기 도 귀찮 고 해서 걍 쓰 기 로 했 습니다 .',
#  'negative\t11 일 에 주문 해서 18 일 에 받 았 습니다 . 상 품평 이 좋 을 리 가 없 겠 죠 ?',
#  'negative\t11 일 에 주문 해서 19 일 에 받 음 . 판매자 한테 문의 하 였으나 답변 도 한참 늦 게 달 고 거짓말 로 또 기다리 게 만들 었 음 . 취소 하 려던 차 에 배송 이 시작 됨 . . 기대 없이 받 았 는데 역시 나 별로 임 .',
#  'negative\t11 일 에 결재 하 고 19 일 에 받 았 는데 , 어떻게 생각 하 셔요 ?',
#  'negative\t11 일 날 주문 해서 19 일 날 받 았 습니다 . 전화 도 안 되 고 이건모 ~~ 속터지 는 줄 알 았 죠 . 무슨 배짱 이 신지 는 모르 겠 으나 늦 으면 늦 게 보낸다고 전화 라도 줘야 하 는 거 아닌가요 ? ?? 기본 이 없 는 회사 인듯 . ...',
#  'negative\t11 일 에 주문 해서 20 일 날 겨우 받 았 습니다 . 물건 이 어디 에 있 는지 도 확인 이 안 되 어 애태우 더니 아무 말 없이 밑 에 집 앞 에 두 고 가버리 는 한진 택배 . .. 물론 판매자 분 은 대응 에 친절 하 시 고 최대한 노력 하 시 는 성의 는 보 았 습니다 만 남 에 집 에 던져 놓 고 간 물건 을 보 니 박스 는 곧 터질 듯이 어딜 그렇게 굴러다니 다 왔 는지 너덜너덜 그지 가 다 되 었 더군요 . .. 뭐 내용물 만 상하 지 않 았 다면 겉모습 이 뭣 이 중허 겠 습니까 만 그래도 애태우 다 받 은 물건 인데 기분 은 참 상하 더군요 . 박스 를 뜯 어 내용물 을 보 고 좋 은 구성 에 맘 풀 자 했 는데 아무리 유통 기한 이 3 년 이 라지만 16 년 제조 상품 을 받 은 거 에 풀 려고 했 던 마음 이 다시 급 상했 습니다 . 몇 일전 에 시키 신 분 들 후기 보 니 다 들 17 년 제조 상품 이 던데 11 일 에 주문 한 사람 들 한테 는 땡처리 개념 으로 파셨 나 하 는 맘 이 들 어 무척 기분 이 상해 이 시간 에 후기 올립니다 .',
#  'negative\t11 일 날 주문 했 고 20 일 날 받 았 네요 추석 전 에 받 겠 지 하 고 주문 했 는데 생각 보다 많이 늦 게 받 게 되 었 네요 제품 은 기존 가지 고 있 던 피셔 부스터 비교 했 을 때 약간 부실 해 보여요 좀 약한 느낌',
#  'negative\t11 일 에 주문 해서 2 주 가까이 걸려 받 음 별로',
#  'negative\t11 일 날 주문 하 고 오늘 받 았 어요 추석 전 에 받 을 줄 알 았 는데 좀 많이 오래 걸렸 네요',
#  'negative\t11 개 를 구매 하 고 각각 다른 곳 으로 보내 야 하 기 때문 에 개별 박스 포장 을 요청 했었 는데 . .. 그냥 보내 주 셨 더라구요 덕분 에 1 시간 동안 따로 박스 포장 다시 했 네요 업체 에서 포장 하 는 건 얼마 안 걸리 겠 죠 ? ? 박스 도 있 고 , 사람 도 있 으니 개인 이 포장 할려면 박스 도 다 사 야 되 고 , 박스 테 잎 도 사 야 되 고 . ... 마인드 가 별루',
#  'negative\t11 일 날 발 주마 감전 새벽 에 주문 해서 20 일 날 상품 받 았 습니다 . 딱 9 일 걸렸 습니다 . 해외 직구 하 는 줄 알 았 습니다 . 배송 문제 발생 시 안내 서비스 부분 과 상품 배송 상태 는 너무 아쉽 습니다 .',
#  'negative\t11 일 에 빼빼 로 데인 데 10 일 날 오후 에 오 는 건 뭐 ?',
#  'negative\t11 일 날 주문 한 제품 을 19 일 날 받 았 습니다 . 11 날 저녁 에 주문 했으니 12 일 날 확 이 하 고 발송 했 더라도 6 영업 일 이 고 날짜 로 치 면 8 일 입니다 . 공식 판매처 에서 900 미리 500 미리 를 구분 을 못 해서 물건 을 잘못 보내 서 주 고 받 고 걸린 시간 입니다 . 온라인 몰 담당자 교육 이 어떻게 되 었 는지 맞교환 이랑 선출 고랑 단어 구분 을 못 하 는 거 같 습니다 . 제 가 알기 론 맞교환 이 란 말 인 반품 접수 할 때 제 가 주문 한 물건 을 받 는 걸로 아 는데 여기 서 는 선출 고 를 맞교환 으로 알 고 있 는 거 같 습니다 . 명색 이 공식 판매처 라고 하 면서 관리 가 안 되 는 거 같 습니다 . 구매 하 시 려는 분 들 은 이 점 참고 하 시 고 현명 한 소비 하 시 기 바랍니다 .',
#  'negative\t11 일 날 티 멤버 쉽 할인 해서 샀 는데 사 고 나 서 검색 해 보 니까 다른 게 더 싸 네여 팩 은 그냥 쏘 쏘 배송 은 빨라요',
#  'negative\t11 일 날 쯤 샀 는데 좀 전 에 받 았 으니 8 일 은 걸렸 네요 . 향 을 몰라 1 번 샀 는데 노란 색향 이 더 나 은 듯 하 구요 . 마트 에서 도 싸 고 오 지 도 않 아 취소 하 고 싶 었 지만 다 막 아 둬서 그냥 기다렸 습니다 . 십 일 절 가격 할인 은 못 받 았 고 , 사은품 있 을 때 라 기다렸 지만 , 너무 느리 고 다신 온라인 주문 안 할 듯 합니다 . 평가 쓰 려고 구매 확정 빨리 한 것 도 후회 할 정도 입니다 .',
#  'negative\t11 월 에 도 샀었 고 이번 달 에 도 3 일 에 물건 받 았 는데 사은품 받 은 적 없 어요 . 저 만 못 받 은 건지 사은품 사진 은 없애 거나 하 셔야 할 것 같 습니다',
#  'negative\t11 일 만 에 물건 받 음 너무 오래 걸리 는 것 만 빼 면 . ..',
#  'negative\t11 일 만 에 받 았 네요 . 배송 이 느려서 별로 네요 .',
#  'negative\t11 일 만 에 물품 받 았 는데 너무너무 실망 했 습니다 . 배송 이 너무너무 느리 고 제품 에 질 도 좋 아 보이 지 않 습니다 . 거실 커튼 주문 은 절대 이곳 에서 하 지 않 겠 습니다 .',
#  'negative\t11 키로 인데 대형 딱 맞 아요 군 기저귀 접착 밴드 가 약한 거 같 아요',
#  'negative\t11 개월 아기 처음 줬 는데 . . 안 먹 어요 ㅜ',
#  'negative\t11 일 날 구입 . . 19 일 날 받 았 네요 . ...',
#  'negative\t11 일 주문 ㅡ 13 일 배송 출발 ㅡ 16 일 택배 받 음 . 가죽 이 생명 인데 다 접혀서 옴 ㅡㅡ',
#  'negative\t11 개 시켰 는디 1 개 왔 다 장난 하 냐',
#  'negative\t11 일 주문 했 는데 18 일 받 았 어요 ! 아무리 휴일 이 포함 되 있 어도 심한 거 아닌가요 ?',
#  'negative\t11 개월 아들 한텐 발진 은 없 구요 키 80 조금 넘 고 10 . 5 키 로 정도 인데 쉬 가 엄청 새 네요 일 욜 에 주문 해서 목 욜 에 받 구 오늘 화요일 인데 자 다가 쉬 가 세 번 샜 어요 ㅡㅡ 옆 선 도 약해서 입히 다 종종 찢어지 네요',
#  'negative\t11 월 초 에 샀 는데 아직 도 안 오 네요 ? ㅋㅋ ㅋㅋ 뭐 하 자는 건지 문의 만 3 건 이상 올렸 는데 그냥 만만 한가 보 죠 ? 적당히 무시 해야지 얼른 환불 처리 해 달 라니까요 ?',
#  'negative\t11 일 날 구매 햇 는데 아직 도 안 오 네요 ? ??',
#  'negative\t11 가 쿠폰 이 안 왔 어요 포장 이 다 뜯겨 서 도착 했 네요 포장 신경 써 주 세요',
#  'negative\t11 일 만 에 옴 해외 배송 인 줄',
#  'negative\t12 + 2 일 때 구매 했 는데 1 개 만 더 왔 길래 들어와 보 니 그새 12 + 1 로 바 껴 있 네요 . 이렇게 장사 하 지 마시 죠',
#  'negative\t12 . 20 구매 해서 2 주 기다렸 네요 . 입 고 예정 날짜 나오 고 그 날짜 되 면 미뤄 지 고 또 예정 날짜 나오 고 또 그날 되 면 미뤄 지 고 몇 번 을 미뤄진 건지 배송 최악 이 구요 . 다신 . 구매 안 하 려고요 제품 은 보들보들 이 가격 에 만족 합니다 .',
#  'negative\t12 . 스판 그린 하트 인데 부엉이 가 왔 음 . 교환 번거로워 구매 확정 함 . 배송 은 빠름 .',
#  'negative\t12 / 21 주문 하 고 아직 도 못 받 았 습니다 두 세트 주문 하 여 한 박스 이리저리 문의 해서 겨우 받 고 한 박스 는 아직 도 못 받 았 네요 두 번 째 주문 인데 처음 에 는 상품 도 좋 고 배송 도 만족 스러웠 는데 두 번 째 는 엉망 이 네요 광주 광역시 인데 용인 으로 배송 완료 되 었 다고 뜨 고 안내 도 없이 안 와서 제 가 사이트 문의 하 여 4 , 5 일 만 에 답변 듣 고 ( 파손 되 어 재 발송 한다는 ) 그것 도 한 세트 는 말 도 없이 미 배송 상태 인데 문의 하 면 다 배송 됐 다는 앵무새 같 은 말 만 되풀이 . . 배송 은 늦 을 수 있 지만 미리 구매자 에게 문자 나 전화 로 공지 는 해야 하 는 거 아닙니까 ?',
#  'negative\t12 / 22 주문 . . 12 / 31 싱 품 수령 . . 상품 에 는 불만 이 없 으나 배송 은 엉망 임다 . ..',
#  'negative\t12 / 24 일 날 계약 했 는데 12 / 31 일 에 설치 받 았 습니다 . 파업 때문 에 기사 님 들 이 설치 를 안 해 주 신다고 오래 걸렸 네요 . 본사 도 전화 연결 이 원활 하 지 않 아서 답답 했 습니다 . 급하 신 분 들 은 추천 하 지 않 습니다 .',
#  'negative\t12 / 3 일 에 주문 했 는데 . . 아직 받 지 도 못한 상품 이 배송 추적 엔 배달 완료 로 되 어 있 네요 . 한진 택배 하루 에 10 통 씩 전화 해도 통화 도 안 되 고 . . 정말 화 만 납니다 .',
#  'negative\t12 / 7 일 주문 해서 3 일 안 에 도착 했 는데 상품 이 주문 한 것 이 아니 어서 교환 신청 을 했 습니다 . 다음 날 물건 회수 는 해 갔 는데 몇 일 기다려도 물건 이 도착 하 지 않 아서 태풍 몰 에 연락 했 더니 바빠서 빠트릴 수 있 다는 답변 을 했 습니다 . 너무 어이없 어 사이트 콜 센터 에 항 의 전화 를 했 더니 12 / 19 일 오늘 5 시 50 분 에 물건 이 도착 했 습니다 . 근데 사은품 으로 온 무 릅 담요 와 10 개 짜리 랜덤 을 넣 지 않 고 물건 2 개 만 달랑 왔 네요 . 지금 까지 사이트 를 믿 고 거래 를 해 왔 는데 이렇게 성 의 없 게 고객 을 기만 하 는 행태 를 보여 주 네요 . 아주 실망 했 습니다 .',
#  ...]

# %%
def get_term_frequency(document):
    term_freq = {}

    words = document.split()

    for w in words:
        term_freq[w] = 1 + (0 if term_freq.get(w) is None else term_freq[w])
    
    return term_freq

# %%
get_term_frequency(lines[10])
# Out:
# {'negative': 1,
#  '"': 2,
#  '화이트': 1,
#  '로': 1,
#  '구매': 1,
#  '했': 1,
#  '는데': 1,
#  '.': 2,
#  '..': 2,
#  '다른': 1,
#  '제품': 1,
#  '으로': 1,
#  '배송': 1,
#  '되': 1,
#  '어': 1,
#  '왔': 1,
#  '어요': 1,
#  '!': 2,
#  '여기': 1,
#  '가': 1,
#  '외국': 1,
#  '이': 1,
#  '아니': 1,
#  '라면': 1,
#  '당장': 1,
#  '반품': 1,
#  '인데': 1,
#  '~~~': 1}

# %%
def get_context_counts(lines, vocab, w_size=2):
    context_cnt = defaultdict(int)

    for line in lines:
        words = line.split()

        for i, w in enumerate(words):
            if w in vocab:
                for c in words[i - w_size:i + w_size]:
                    if w != c:
                        context_cnt[(w, c)] += 1
    return context_cnt

# %%
def get_co_occurrence_df(context_cnt, vocab):
    data = []

    for word1 in vocab:
        row = []

        for word2 in vocab:
            try :
                count = context_cnt[(word1, word2)]
            except KeyError:
                count = 0
            row.append(count)
            
        data.append(row)

    return pd.DataFrame(data, index=vocab, columns=vocab)

# %%
term_freq = pd.Series(
    get_term_frequency(' '.join(lines))
).sort_values(ascending=False)

term_freq
# Out:
# .             362139
# 고             208598
# 이             198967
# 하             171351
# positive      170652
#                ...
# 방수형                1
# 퀄릴티도               1
# ㅡㅡ더                1
# ㅡㅡ주문상태확인하고         1
# ㅜㅜ건반도              1
# Length: 65614, dtype: int64

# %%
vector_size = 800

# %%
term_freq.index[:vector_size]
# Out:
# Index(['.', '고', '이', '하', 'positive', '도', '네요', '좋', 'negative', '에',
#        ...
#        '털', '밝', '치수', '건가요', '사료', '바랍니다', '누가', '확실히', '으려고', '품평'],
#       dtype='object', length=800)

# %%
context_cnt = pd.Series(
    get_context_counts(
        lines,
        term_freq.index[:vector_size],
        w_size=4
    )
)

context_cnt
# Out:
# negative  !            63
# !         negative    200
# 아서        negative    338
#           !           179
#           다           596
#                      ...
# 어여        v             1
# ㅇㅇ        에요            4
#           베이            2
#           굿             3
#           입니다           4
# Length: 2615014, dtype: int64

# %%
df = get_co_occurrence_df(context_cnt, term_freq.index[:vector_size])

df
# Out:
#               .      고      이      하  positive      도     네요      좋  negative  \
# .             0  38014  49026  38350      3792  34475  59303  31834      4768
# 고         37188      0  22532  55069     10332  75470  12892  29640      3595
# 이         44145  21874      0  14743      3101   9912  26440  13216      4329
# 하         35949  55007  16361      0      4253  21907  23599  14699      2146
# positive    971   1866   1136    981         0    178   1011   4305         0
# ...         ...    ...    ...    ...       ...    ...    ...    ...       ...
# 바랍니다        747     79     56    391         1     21     15     24         1
# 누가          285    166    106     90         5     52    104     24        16
# 확실히         261    152    216    141        19     65    178    145         4
# 으려고         164     63     38    129        72     22     34     13        28
# 품평          213    174    228    100        12     86     67    213        27
#
#               에  ...    털    밝   치수  건가요   사료  바랍니다   누가  확실히  으려고   품평
# .         26418  ...  281  283  202  177  177   746  282  282  192  210
# 고         16531  ...  257  309   78   53  126    53  147  153   69  203
# 이         15657  ...  442  210   38  116  167    58   83  224   55  218
# 하         11490  ...   68   85  160  160   74   368   84  136  135   87
# positive    802  ...    1   22    1    0    4     0    0    4    0    1
# ...         ...  ...  ...  ...  ...  ...  ...   ...  ...  ...  ...  ...
# 바랍니다         25  ...    0    0    0    2    0     0    0    1    0    1
# 누가           51  ...    0    0    1    4    0     0    0    0    0    0
# 확실히          59  ...    1    7    1    1    0     1    0    0    1    0
# 으려고         149  ...    1    2    6    0    1     0    0    1    0    2
# 품평           98  ...    1    0    1    1    0     1    0    0    2    0
#
# [800 rows x 800 columns]

# %%
df.values.shape
# Out:
# (800, 800)

# %% [markdown]
# ### Similarity Measures

# %%
import torch

# %%
def get_L1_distance(x1, x2):
    return ((x1 - x2).abs()).sum()

# %%
def get_L2_distance(x1, x2):
    return ((x1 - x2) ** 2).sum() ** .5

# %%
def get_infinity_distance(x1, x2):
    return ((x1 - x2).abs()).max()

# %%
def get_cosine_similarity(x1, x2):
    return (x1 * x2).sum() / (((x1**2).sum() ** .5) * ((x2**2).sum() ** .5) + 1e-10)

# %%
def get_nearest(query, dataframe, metric, top_k, ascending=True):
    vector = torch.from_numpy(dataframe.loc[query].values).float()
    distances = dataframe.apply(
        lambda x: metric(vector, torch.from_numpy(x.values).float()),
        axis=1
    )
    top_distances = distances.sort_values(ascending=ascending)[:top_k]

    print(', '.join([f'{k} ({v:.1f})' for k, v in top_distances.items()]))

# %%
print('L1 distance:')
get_nearest('반품', df, get_L1_distance, 10)
print('\nL2 distance:')
get_nearest('반품', df, get_L2_distance, 10)
print('\nInfinity distance:')
get_nearest('반품', df, get_infinity_distance, 10)
print('\nCosine Similarity:')
get_nearest('반품', df, get_cosine_similarity, 10, ascending=False)
# Out:
# L1 distance:
# 반품 (0.0), 교환 (27890.0), ㅠㅠ (33880.0), ㅠ (34704.0), 말 (35802.0), ㅡㅡ (36658.0), 다시 (36880.0), 뭐 (37059.0), 진짜 (37214.0), 그리고 (37588.0)
#
# L2 distance:
# 반품 (0.0), 교환 (3837.5), 다고 (4556.4), 확인 (4997.4), 다시 (5008.6), 깔끔 (5016.8), 불편 (5051.2), 말 (5077.9), 긴 (5153.3), 못 (5157.6)
#
# Infinity distance:
# 반품 (0.0), 다고 (1858.0), 를 (1875.0), 긴 (1936.0), 라고 (2072.0), 여 (2176.0), 교환 (2215.0), 확인 (2258.0), 로 (2368.0), 깔끔 (2422.0)
#
# Cosine Similarity:
# 반품 (1.0), 교환 (0.9), 환불 (0.9), 조립 (0.9), 그냥 (0.9), 불편 (0.9), 확인 (0.9), 사용 (0.9), 착용 (0.9), 기 (0.8)
